# %%
import os
import glob
import pylab
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
def Hbeta(D=np.array([]), beta=1.0):
    """
        Compute the perplexity and the P-row for a specific value of the
        precision of a Gaussian distribution.
    """

    # Compute P-row and corresponding perplexity
    P = np.exp(-D.copy() * beta)
    sumP = sum(P)
    H = np.log(sumP) + beta * np.sum(D * P) / sumP
    P = P / sumP
    return H, P


def x2p(X=np.array([]), tol=1e-5, perplexity=30.0):
    """
        Performs a binary search to get P-values in such a way that each
        conditional Gaussian has the same perplexity.
    """

    # Initialize some variables
    print("Computing pairwise distances...")
    (n, d) = X.shape
    sum_X = np.sum(np.square(X), 1)
    D = np.add(np.add(-2 * np.dot(X, X.T), sum_X).T, sum_X)
    P = np.zeros((n, n))
    beta = np.ones((n, 1))
    logU = np.log(perplexity)

    # Loop over all datapoints
    for i in range(n):

        # Print progress
        if i % 500 == 0:
            print("Computing P-values for point %d of %d..." % (i, n))

        # Compute the Gaussian kernel and entropy for the current precision
        betamin = -np.inf
        betamax = np.inf
        Di = D[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))]
        (H, thisP) = Hbeta(Di, beta[i])

        # Evaluate whether the perplexity is within tolerance
        Hdiff = H - logU
        tries = 0
        while np.abs(Hdiff) > tol and tries < 50:

            # If not, increase or decrease precision
            if Hdiff > 0:
                betamin = beta[i].copy()
                if betamax == np.inf or betamax == -np.inf:
                    beta[i] = beta[i] * 2.
                else:
                    beta[i] = (beta[i] + betamax) / 2.
            else:
                betamax = beta[i].copy()
                if betamin == np.inf or betamin == -np.inf:
                    beta[i] = beta[i] / 2.
                else:
                    beta[i] = (beta[i] + betamin) / 2.

            # Recompute the values
            (H, thisP) = Hbeta(Di, beta[i])
            Hdiff = H - logU
            tries += 1

        # Set the final row of P
        P[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))] = thisP

    # Return final P-matrix
    print("Mean value of sigma: %f" % np.mean(np.sqrt(1 / beta)))
    return P


def pca(X=np.array([]), no_dims=50):
    """
        Runs PCA on the NxD array X in order to reduce its dimensionality to
        no_dims dimensions.
    """

    print("Preprocessing the data using PCA...")
    (n, d) = X.shape
    X = X - np.tile(np.mean(X, 0), (n, 1))
    (l, M) = np.linalg.eig(np.dot(X.T, X))
    Y = np.dot(X, M[:, 0:no_dims])
    return Y


def tsne(X=np.array([]), no_dims=2, initial_dims=50, perplexity=30.0):
    """
        Runs t-SNE on the dataset in the NxD array X to reduce its
        dimensionality to no_dims dimensions. The syntaxis of the function is
        `Y = tsne.tsne(X, no_dims, perplexity), where X is an NxD NumPy array.
    """

    # Check inputs
    if isinstance(no_dims, float):
        print("Error: array X should have type float.")
        return -1
    if round(no_dims) != no_dims:
        print("Error: number of dimensions should be an integer.")
        return -1

    # Initialize variables
    X = pca(X, initial_dims).real
    (n, d) = X.shape
    max_iter = 1000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    Y = np.random.randn(n, no_dims)
    dY = np.zeros((n, no_dims))
    iY = np.zeros((n, no_dims))
    gains = np.ones((n, no_dims))

    # Compute P-values
    P = x2p(X, 1e-5, perplexity)
    P = P + np.transpose(P)
    P = P / np.sum(P)
    P = P * 4.                         # early exaggeration
    P = np.maximum(P, 1e-12)

    # Run iterations
    for iter in range(max_iter):

        # Compute pairwise affinities
        sum_Y = np.sum(np.square(Y), 1)
        num = -2. * np.dot(Y, Y.T)
        num = 1. / (1. + np.add(np.add(num, sum_Y).T, sum_Y))   # ||yi - yj||^2 = np.add(np.add(num, sum_Y).T, sum_Y) 
        num[range(n), range(n)] = 0.
        Q = num / np.sum(num)
        Q = np.maximum(Q, 1e-12)

        # Compute gradient
        PQ = P - Q
        for i in range(n):
            dY[i, :] = np.sum(np.tile(PQ[:, i] * num[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)

        # Perform the update
        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum
        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
                (gains * 0.8) * ((dY > 0.) == (iY > 0.))
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - np.tile(np.mean(Y, 0), (n, 1))

        # Compute current value of cost function
        if (iter + 1) % 10 == 0:
            C = np.sum(P * np.log(P / Q))
            print("Iteration %d: error is %f" % (iter + 1, C))

        # Stop lying about P-values
        if iter == 100:
            P = P / 4.
            
        # save scatter plot
        if iter % 10 == 0:
            pylab.clf()
            plt.title('iter:{}'.format(str(iter).zfill(4)))
            pylab.scatter(Y[:, 0], Y[:, 1], 10, labels)
            pylab.savefig(os.path.join('img/tsne','iter{}.png'.format(str(iter).zfill(4))))


    # Return solution
    return Y, P, Q

# %% [markdown]
# # main

# %%
if __name__ == "__main__":
    print("Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.")
    print("Running example on 2,500 MNIST digits...")
    X = np.loadtxt("mnist2500_X.txt")
    labels = np.loadtxt("mnist2500_labels.txt")
    Y, P, Q = tsne(X, 2, 50, 20.0)
    pylab.scatter(Y[:, 0], Y[:, 1], 10, labels)
    pylab.show()
# Out:
# Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.
# Running example on 2,500 MNIST digits...
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.386597
# Iteration 10: error is 23.676563
# Iteration 20: error is 21.209519
# Iteration 30: error is 17.763203
# Iteration 40: error is 16.622646
# Iteration 50: error is 16.345163
# Iteration 60: error is 16.229052
# Iteration 70: error is 16.145651
# Iteration 80: error is 16.066175
# Iteration 90: error is 16.004843
# Iteration 100: error is 15.953394
# Iteration 110: error is 2.305495
# Iteration 120: error is 2.067202
# Iteration 130: error is 1.887540
# Iteration 140: error is 1.751505
# Iteration 150: error is 1.646329
# Iteration 160: error is 1.564684
# Iteration 170: error is 1.499206
# Iteration 180: error is 1.445524
# Iteration 190: error is 1.400820
# Iteration 200: error is 1.363177
# Iteration 210: error is 1.331382
# Iteration 220: error is 1.304141
# Iteration 230: error is 1.280680
# Iteration 240: error is 1.260291
# Iteration 250: error is 1.242312
# Iteration 260: error is 1.226310
# Iteration 270: error is 1.211995
# Iteration 280: error is 1.199142
# Iteration 290: error is 1.187538
# Iteration 300: error is 1.177050
# Iteration 310: error is 1.167507
# Iteration 320: error is 1.158778
# Iteration 330: error is 1.150738
# Iteration 340: error is 1.143370
# Iteration 350: error is 1.136624
# Iteration 360: error is 1.130398
# Iteration 370: error is 1.124630
# Iteration 380: error is 1.119256
# Iteration 390: error is 1.114238
# Iteration 400: error is 1.109560
# Iteration 410: error is 1.105186
# Iteration 420: error is 1.101074
# Iteration 430: error is 1.097210
# Iteration 440: error is 1.093589
# Iteration 450: error is 1.090187
# Iteration 460: error is 1.086977
# Iteration 470: error is 1.083948
# Iteration 480: error is 1.081083
# Iteration 490: error is 1.078368
# Iteration 500: error is 1.075785
# Iteration 510: error is 1.073331
# Iteration 520: error is 1.071001
# Iteration 530: error is 1.068793
# Iteration 540: error is 1.066686
# Iteration 550: error is 1.064670
# Iteration 560: error is 1.062716
# Iteration 570: error is 1.060877
# Iteration 580: error is 1.059134
# Iteration 590: error is 1.057471
# Iteration 600: error is 1.055886
# Iteration 610: error is 1.054373
# Iteration 620: error is 1.052921
# Iteration 630: error is 1.051523
# Iteration 640: error is 1.050170
# Iteration 650: error is 1.048880
# Iteration 660: error is 1.047648
# Iteration 670: error is 1.046468
# Iteration 680: error is 1.045330
# Iteration 690: error is 1.044233
# Iteration 700: error is 1.043168
# Iteration 710: error is 1.042133
# Iteration 720: error is 1.041130
# Iteration 730: error is 1.040159
# Iteration 740: error is 1.039230
# Iteration 750: error is 1.038340
# Iteration 760: error is 1.037481
# Iteration 770: error is 1.036649
# Iteration 780: error is 1.035840
# Iteration 790: error is 1.035053
# Iteration 800: error is 1.034291
# Iteration 810: error is 1.033554
# Iteration 820: error is 1.032842
# Iteration 830: error is 1.032151
# Iteration 840: error is 1.031478
# Iteration 850: error is 1.030824
# Iteration 860: error is 1.030190
# Iteration 870: error is 1.029572
# Iteration 880: error is 1.028970
# Iteration 890: error is 1.028386
# Iteration 900: error is 1.027821
# Iteration 910: error is 1.027271
# Iteration 920: error is 1.026732
# Iteration 930: error is 1.026201
# Iteration 940: error is 1.025695
# Iteration 950: error is 1.025205
# Iteration 960: error is 1.024727
# Iteration 970: error is 1.024260
# Iteration 980: error is 1.023802
# Iteration 990: error is 1.023354
# Iteration 1000: error is 1.022918

# %% [markdown]
# # plot similarity

# %%
def plot_similarity(P, Q):
    pylab.title('TSNE high-dim')
    pylab.hist(P.flatten(), bins=1000,log=True)
    pylab.show()
    pylab.title('TSNE low-dim')
    pylab.hist(Q.flatten(), bins=1000,log=True)
    pylab.show()
    
plot_similarity(P,Q)

# %% [markdown]
# # GIF

# %%
# Create the frames
frames = []
imgs = glob.glob("img/tsne/*.png")
for i in imgs:
    new_frame = Image.open(i)
    frames.append(new_frame)

    
# Save into a GIF file that loops forever
frames[0].save('GIF/tsne.gif', format='GIF',
               append_images=frames[1:],
               save_all=True,
               duration=100, loop=0)
