# %% [markdown]
# ## 1. Random Data Generator

# %% [markdown]
# ### a. Univariate gaussian data generator
# since a N(μ, σ2) can be generated as X = μ + σZ
#
# Marsaglia polar method https://en.wikipedia.org/wiki/Normal_distribution#Generating_values_from_normal_distribution

# %%
import numpy as np
from matrixTool import inverse
import matplotlib.pyplot as plt
from math import exp, pi, sqrt, log

# %%
m = 20    # mean
s = 10    # variance

# %%
def gaussian_data_generator(m, s):
    while(True):
        U = np.random.uniform(-1, 1)
        V = np.random.uniform(-1, 1)
        S = U**2 + V**2   # 規定S要小於1
        if S < 1:
            break
        
    Z = U * sqrt((-2) * log(S) / S)
    p = m + sqrt(s) * Z
    return p

# %%
# 驗證，參考https://kknews.cc/zh-tw/news/pg8kj88.html
ps=[]
for i in range(10000):
    ps.append(gaussian_data_generator(m,s))
plt.hist(ps, bins=100)       # bins控制直方塊的數量
plt.title('mean:{}, varinance:{}'.format(m,s))
plt.show()

# %% [markdown]
# ### b. Polynomial basis linear model data generator

# %%
n = 3      # basis number
a = 10     # variance 
w = np.array([2, 4, 5])

# %%
def linearmodel_data_generator(n, a, w):
    x = np.random.uniform(-1, 1)                # x is uniformly distributed
    y = 0
    for i in range(n):
        y += (w[i]*(x**i))
    
    e = gaussian_data_generator(0, a)
    return x, y+e

# %%
linearmodel_data_generator(n, a, w)
# Out:
# (0.7542712274941661, 5.275955740469186)

# %% [markdown]
# ## 2. Sequential Estimator
# Welford's online algorithm
# https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance#Online_algorithm

# %%
# 正確mean & variance
m = 3.0
s = 5.0

# %%
# 一開始mean & variance都是0
m_est = 0
s_est = 0

n = 1  # n:總point數
print('Data point source function: N({},{})'.format(m, s))

for i in range(1000):
    new_point = gaussian_data_generator(m, s)                             # 我一直丟~N(m, s)的點進去，這樣會越來越偏向該高斯分布
    n += 1
    new_m = m + (new_point - m) / n
    new_s = s + (new_point - m)**2 / n - s / (n-1)
    print('Add data point: {}'.format(new_point))
    print('Mean={}  Variance={}'.format(new_m, new_s))
    print()
    
    # 自訂義收斂:如果|新mean-舊mean| < 1e-5，|新var-舊var| < 1e-5，就當作收斂
    if abs(m_est - new_m) < 1e-5 or abs(s_est-new_s) < 1e-5:
        break
    else:
        m_est = new_m
        s_est = new_s
# Out:
# Data point source function: N(3.0,5.0)
# Add data point: 1.859283978201042
# Mean=2.4296419891005208  Variance=0.6506165211944204
#
# Add data point: -0.248053425978636
# Mean=1.917315524673788  Variance=6.016617019337184
#
# Add data point: 1.7528825493436284
# Mean=2.688220637335907  Variance=3.722158817266245
#
# Add data point: 3.4370784237533667
# Mean=3.0874156847506735  Variance=3.7882075097021453
#
# Add data point: 4.530521502883649
# Mean=3.255086917147275  Variance=4.390416011798203
#
# Add data point: 6.086484917951355
# Mean=3.4409264168501936  Variance=5.527579402201122
#
# Add data point: 1.974882816285366
# Mean=2.8718603520356707  Variance=4.417072440757663
#
# Add data point: 3.4065588546758523
# Mean=3.045173206075095  Variance=4.393365566923927
#
# Add data point: 4.904870735876944
# Mean=3.1904870735876942  Variance=4.807297696484482
#
# Add data point: 3.343703770886063
# Mean=3.0312457973532783  Variance=4.510739298374664
#
# Add data point: 1.7342491903364958
# Mean=2.8945207658613747  Variance=4.678964971468197
#
# Add data point: 1.0155350281838984
# Mean=2.8473488483218383  Variance=4.886264196746032
#
# Add data point: 2.400886559273064
# Mean=2.9572061828052187  Variance=4.64102296644602
#
# Add data point: 2.107306916977951
# Mean=2.94048712779853  Variance=4.695983872222171
#
# Add data point: 1.7352781765117542
# Mean=2.9209548860319847  Variance=4.766636747342131
#
# Add data point: 3.2816550797882904
# Mean=3.0165679458698995  Variance=4.692166446115914
#
# Add data point: 5.060591152582765
# Mean=3.114477286254598  Variance=4.941773236169086
#
# Add data point: 3.036753370352762
# Mean=3.001934387913303  Variance=4.722293317497606
#
# Add data point: 1.4163091497715419
# Mean=2.920815457488577  Variance=4.862245940718024
#
# Add data point: 1.2815690057231874
# Mean=2.918169952653485  Variance=4.89061928962339
#
# Add data point: 4.2068849009992455
# Mean=3.054858404590875  Variance=4.828112542098396
#
# Add data point: 1.9473667571372315
# Mean=2.954233337266836  Variance=4.8209027833350895
#
# Add data point: 3.556277534642632
# Mean=3.02317823061011  Variance=4.795502224633344
#
# Add data point: 0.9541880960607325
# Mean=2.9181675238424294  Variance=4.9590805205186514
#
# Add data point: 4.9668701136447915
# Mean=3.0756488505247996  Variance=4.948791463228811
#
# Add data point: 4.722887574964844
# Mean=3.0638106509246237  Variance=4.917630885320761
#
# Add data point: 3.0893049531686305
# Mean=3.0031894626131654  Variance=4.815099649624116
#
# Add data point: 1.4200935428214572
# Mean=2.9455204669938433  Variance=4.90750113740907
#
# Add data point: 4.680177649752027
# Mean=3.056005921658401  Variance=4.921686104720759
#
# Add data point: -0.12139152516417306
# Mean=2.8993099508011557  Variance=5.147626399570969
#
# Add data point: 3.3072233055063744
# Mean=3.009600728297074  Variance=4.841659244902051
#
# Add data point: 3.5699391941831844
# Mean=3.0172708846722176  Variance=4.853593354092914
#
# Add data point: 2.8469504902072176
# Mean=2.995498543829624  Variance=4.849173794145078
#
# Add data point: 2.984882613098841
# Mean=2.9995680746599667  Variance=4.852947706053065
#
# Add data point: 1.7717349242109237
# Mean=2.9658815256725255  Variance=4.8990493875985
#
# Add data point: 1.2247970584901
# Mean=2.9520215421213543  Variance=4.946282610666392
#
# Add data point: 1.3151068120961171
# Mean=2.9556607055814768  Variance=4.939571839987099
#
# Add data point: 3.229375778029691
# Mean=3.0058814302058896  Variance=4.869770110260982
#
# Add data point: 6.147337867717854
# Mean=3.0786834466929465  Variance=5.119438263134141
#
# Add data point: 0.1506769532673946
# Mean=2.930504315933351  Variance=5.07301565425955
#
# Add data point: 1.9485456199797995
# Mean=2.974965371904281  Variance=4.904371549851225
#
# Add data point: 6.291706132340336
# Mean=3.076551305403264  Variance=5.132936782386962
#
# Add data point: 4.887503282285717
# Mean=3.04289780187013  Variance=4.96469067206527
#
# Add data point: 2.9970456043510687
# Mean=2.9999343467633572  Variance=4.886363830329273
#
# Add data point: 4.246854612335493
# Mean=3.0271055350507714  Variance=4.922685550286765
#
# Add data point: 0.11719467983288112
# Mean=2.938663716592189  Variance=5.068124911953403
#
# Add data point: 1.443171476737552
# Mean=2.9675660724320325  Variance=4.944111084835836
#
# Add data point: 5.879245235991238
# Mean=3.058760106856964  Variance=5.065018091067583
#
# Add data point: 2.1960649843971702
# Mean=2.9839212996879434  Variance=4.910885413859716
#
# Add data point: -0.10890843765733793
# Mean=2.9390410110263265  Variance=5.089515915171314
#
# Add data point: 1.9986015492511802
# Mean=2.9807423374855997  Variance=4.92124537772069
#
# Add data point: 4.265774664817547
# Mean=3.023882540845614  Variance=4.934076068980003
#
# Add data point: -0.34201458492245784
# Mean=2.9381108410199546  Variance=5.112494849318387
#
# Add data point: 1.2304373267322797
# Mean=2.9678261332133142  Variance=4.964341081127815
#
# Add data point: 3.357014727204739
# Mean=3.0063752629857987  Variance=4.911366971866642
#
# Add data point: 4.097841875812956
# Mean=3.019260383786192  Variance=4.931859141578996
#
# Add data point: 0.3219712481640782
# Mean=2.9538270904855874  Variance=5.035933080989901
#
# Add data point: 3.8882062603916325
# Mean=3.0150543433964683  Variance=4.9271644654991045
#
# Add data point: 2.408089122008886
# Mean=2.990134818700148  Variance=4.921093545412873
#
# Add data point: 1.4681209610141794
# Mean=2.974887228869085  Variance=4.955136394372964
#
# Add data point: 0.4638838922381061
# Mean=2.9590949014877115  Variance=5.021772866111848
#
# Add data point: 0.41642154027021405
# Mean=2.9589908180995272  Variance=5.025305277718879
#
# Add data point: -1.3826738055122885
# Mean=2.9315207217888704  Variance=5.220757259471227
#
# Add data point: 5.058582639416892
# Mean=3.031670502144875  Variance=4.987071345897055
#
# Add data point: 8.548729264884422
# Mean=3.0840716555285517  Variance=5.389567778455481
#
# Add data point: 2.8974289624604395
# Mean=2.9984690889919468  Variance=4.924399451372901
#
# Add data point: -1.0345954691986279
# Mean=2.9406677136882555  Variance=5.164754907858919
#
# Add data point: 4.721574941117951
# Mean=3.0249503614654776  Variance=4.969424505306096
#
# Add data point: 2.07380937101511
# Mean=2.9867687053002157  Variance=4.9397909330443355
#
# Add data point: 3.1630411951248183
# Mean=3.002296354860913  Variance=4.928945829012383
#
# Add data point: 0.8760444197914348
# Mean=2.9705006169415475  Variance=4.992232844048441
#
# Add data point: 4.049939787440112
# Mean=3.014382736814248  Variance=4.9456565631891145
#
# Add data point: 0.8295558626694386
# Mean=2.9706696738198572  Variance=4.995166683818753
#
# Add data point: 4.066339037745317
# Mean=3.014217853836604  Variance=4.94759348501136
#
# Add data point: 1.5527193897569134
# Mean=2.980956834075749  Variance=4.960894138133144
#
# Add data point: 1.4995415200471016
# Mean=2.980513526234378  Variance=4.9634491711217965
#
# Add data point: 8.569973395079803
# Mean=3.071409915321536  Variance=5.332816263550792
#
# Add data point: 2.0149091820021736
# Mean=2.987530495974711  Variance=4.948181029817735
#
# Add data point: 5.259899852631644
# Mean=3.0282487481578957  Variance=5.00054820255855
#
# Add data point: 1.2442220782808822
# Mean=2.9783237293614926  Variance=4.9755587174123
#
# Add data point: 1.8782563380282025
# Mean=2.9863201992442465  Variance=4.953616834733075
#
# Add data point: 6.991569629685831
# Mean=3.0480912003576606  Variance=5.130983765046677
#
# Add data point: 4.162971611488747
# Mean=3.0138449001367706  Variance=4.95586026196754
#
# Add data point: 4.805325487881525
# Mean=3.0212391233868416  Variance=4.978819721266716
#
# Add data point: 3.96838294544426
# Mean=3.0112602668074913  Variance=4.952080720925762
#
# Add data point: 3.311325324615171
# Mean=3.003578452007071  Variance=4.9429745278490005
#
# Add data point: 3.9381251646832505
# Mean=3.010660513235037  Variance=4.952529631366411
#
# Add data point: 4.303673496417062
# Mean=3.0146480168136747  Variance=4.962278049476878
#
# Add data point: 5.213581416805241
# Mean=3.024595349075614  Variance=4.998264032372718
#
# Add data point: 7.149177706236705
# Mean=3.0455953594091945  Variance=5.133627693212925
#
# Add data point: 4.681967372144349
# Mean=3.0182822540450474  Variance=4.975805099847969
#
# Add data point: 5.353749915312303
# Mean=3.025309138874326  Variance=5.005223557395116
#
# Add data point: 3.2640059301333206
# Mean=3.0028085737248227  Variance=4.946978039258354
#
# Add data point: 2.493348627109192
# Mean=2.994666827653781  Variance=4.949510569729373
#
# Add data point: 4.198080241353903
# Mean=3.012480002514103  Variance=4.962320465476826
#
# Add data point: 5.560892539932645
# Mean=3.026400954019924  Variance=5.015526672863396
#
# Add data point: 4.68578858070998
# Mean=3.017201924292959  Variance=4.977452415786731
#
# Add data point: 0.4360428419389657
# Mean=2.9741014428478683  Variance=5.015382382830396
#
# Add data point: 4.556136495445446
# Mean=3.0155613649544546  Variance=4.973710557419523
#
# Add data point: 7.086888459509841
# Mean=3.040464242173365  Variance=5.115372844361136
#
# Add data point: 2.355949467493118
# Mean=2.9936857790930698  Variance=4.954561726842425
#
# Add data point: -1.0960683026188676
# Mean=2.960232346576516  Variance=5.113871416814329
#
# Add data point: 4.242172371497693
# Mean=3.0119439651105546  Variance=4.9662927741460745
#
# Add data point: 2.9894596532212416
# Mean=2.999899615744964  Variance=4.9519241350079355
#
# Add data point: 4.354280667470223
# Mean=3.012776232711983  Variance=4.969683557345892
#
# Add data point: 3.003702523069317
# Mean=3.000034603019339  Variance=4.952830316797723
#
# Add data point: 0.9523562447142631
# Mean=2.9810403355992063  Variance=4.992093666449982
#
# Add data point: 4.2047922429076925
# Mean=3.01105313984319  Variance=4.967020440846552
#
# Add data point: 1.880026358416868
# Mean=2.9898184214401535  Variance=4.965531539983708
#
# Add data point: 5.819201125035
# Mean=3.0253982083336486  Variance=5.02614811205355
#
# Add data point: 1.5756048016851762
# Mean=2.987282185729332  Variance=4.973070148535155
#
# Add data point: 3.8078086979481136
# Mean=3.007148749539364  Variance=4.961131964914494
#
# Add data point: 3.2814362900626723
# Mean=3.0024687393865146  Variance=4.956447005243453
#
# Add data point: 0.5066485244460397
# Mean=2.97831868282127  Variance=5.010199495056733
#
# Add data point: 5.226883696186674
# Mean=3.0191972732429884  Variance=4.999271833926486
#
# Add data point: -0.5175784841073967
# Mean=2.9699352266315606  Variance=5.062651751654525
#
# Add data point: 0.42133205797547424
# Mean=2.9781468818472496  Variance=5.013616892478729
#
# Add data point: 3.6559014299112493
# Mean=3.0055117767219435  Variance=4.961242300877341
#
# Add data point: 2.7329037779870595
# Mean=2.997774198149892  Variance=4.958577696542425
#
# Add data point: -1.5993959997516018
# Mean=2.9619884628119704  Variance=5.133163445420366
#
# Add data point: 6.009163423650782
# Mean=3.0246652739643505  Variance=5.032899526198263
#
# Add data point: 1.0512582715493697
# Mean=2.9841565713134095  Variance=4.989891144045913
#
# Add data point: 0.9309906006434767
# Mean=2.98331444032777  Variance=4.993872173291303
#
# Add data point: 8.642782808944492
# Mean=3.045142262471556  Variance=5.214405401986195
#
# Add data point: -1.9232295387649643
# Mean=2.9609267496923417  Variance=5.152366580090221
#
# Add data point: 2.3477412891900666
# Mean=2.9948641046392916  Variance=4.9636673928042905
#
# Add data point: -0.06315411219357703
# Mean=2.976069108498488  Variance=5.033933929971158
#
# Add data point: 1.336820467153475
# Mean=2.9871071354042904  Variance=4.9823806485153455
#
# Add data point: 2.9312799656168513
# Mean=2.999471384350899  Variance=4.961276636563101
#
# Add data point: -0.5129196355234908
# Mean=2.9731838195761564  Variance=5.055741548299122
#
# Add data point: 2.7749045684818747
# Mean=2.998294731579408  Variance=4.962215909199689
#
# Add data point: 4.365469485862393
# Mean=3.010266687863627  Variance=4.976140061119868
#
# Add data point: 2.0700067851654085
# Mean=2.9930597521281  Variance=4.968860398467731
#
# Add data point: 5.063488538064406
# Mean=3.0152851002819587  Variance=4.994227196399166
#
# Add data point: 2.1971547877828144
# Mean=2.994096726380756  Variance=4.967702377924581
#
# Add data point: 2.1871073066568765
# Mean=2.994066476690926  Variance=4.968058611861374
#
# Add data point: 3.179678708884927
# Mean=3.001302019629601  Variance=4.963737594841026
#
# Add data point: 2.9255467344854895
# Mean=2.9994643649962986  Variance=4.963807995717179
#
# Add data point: 2.4555930892683007
# Mean=2.9961113792090592  Variance=4.966145769010221
#
# Add data point: 3.8580844165465153
# Mean=3.0060857050818903  Variance=4.969507762980182
#
# Add data point: 3.8240807688395395
# Mean=3.005803385696053  Variance=4.969321465638474
#
# Add data point: 0.04501167559555208
# Mean=2.9793357459831857  Variance=5.02585136174658
#
# Add data point: 3.9892072468240456
# Mean=3.0068694947696115  Variance=4.971830319043084
#
# Add data point: 0.45996315755759154
# Mean=2.9824825045348797  Variance=5.009772861646501
#
# Add data point: 3.6330363506631307
# Mean=3.004335865415501  Variance=4.968262001798906
#
# Add data point: 2.1710188456763957
# Mean=2.9943606724195675  Variance=4.97042832094477
#
# Add data point: 6.227466298985709
# Mean=3.0218072047228763  Variance=5.036368412875988
#
# Add data point: 3.2962067172931255
# Mean=3.0019879645455916  Variance=4.96680506466836
#
# Add data point: 1.664829894214987
# Mean=2.9910988659614333  Variance=4.978327481096015
#
# Add data point: 5.891750275886491
# Mean=3.0191506640787185  Variance=5.02204560479971
#
# Add data point: 3.212524455175171
# Mean=3.0013981872051  Variance=4.96718456619254
#
# Add data point: 0.6924861493651844
# Mean=2.98491821012657  Variance=5.001906702183199
#
# Add data point: 1.7834381985131167
# Mean=2.992100248042293  Variance=4.976930797910876
#
# Add data point: 6.697354230110363
# Mean=3.0238538982587766  Variance=5.055728779164177
#
# Add data point: 2.7325068562129475
# Mean=2.9982853003603394  Variance=4.968200605881134
#
# Add data point: -1.1254796663014544
# Mean=2.9737230594503092  Variance=5.076353701879079
#
# Add data point: 2.5785653994382622
# Mean=2.997332692401508  Variance=4.9692769619543835
#
# Add data point: 1.7860446640013843
# Mean=2.992365060779883  Variance=4.977622905586033
#
# Add data point: 6.37310685857744
# Mean=3.021081917866109  Variance=5.039665020865636
#
# Add data point: 4.641482467134258
# Mean=3.0101955432741256  Variance=4.985485805527386
#
# Add data point: 3.725218329526438
# Mean=3.0044766563551013  Variance=4.972190652622592
#
# Add data point: 1.7327641553838493
# Mean=2.992225546965545  Variance=4.978987868026683
#
# Add data point: 3.4026894327278767
# Mean=3.002455423370292  Variance=4.9703139264183225
#
# Add data point: 0.8196562026076082
# Mean=2.986785795167319  Variance=4.99832370466636
#
# Add data point: 2.9885962209849297
# Mean=2.9999313025360537  Variance=4.969697753107668
#
# Add data point: 2.2963175373925147
# Mean=2.9957863325592364  Variance=4.972844601953614
#
# Add data point: 0.13492435736616581
# Mean=2.9829459783176557  Variance=5.018920942370555
#
# Add data point: 3.53529354266012
# Mean=3.00316741741219  Variance=4.971933593325749
#
# Add data point: 3.910129363850808
# Mean=3.0053537021402987  Variance=4.975286762706628
#
# Add data point: 0.7293958739868436
# Mean=2.986721613298169  Variance=5.000738194926094
#
# Add data point: 4.724651169999678
# Mean=3.010027041686045  Variance=4.988053383093601
#
# Add data point: 1.705001112101113
# Mean=2.9925144572953823  Variance=4.98062400203594
#
# Add data point: -1.6880215082686432
# Mean=2.9730573476536284  Variance=5.097405999585548
#
# Add data point: 1.7123109134247578
# Mean=2.9926417766481417  Variance=4.980739471722863
#
# Add data point: 0.4033978112748038
# Mean=2.985246578473152  Variance=5.00973733805637
#
# Add data point: 2.8824397794988252
# Mean=2.9993358179632703  Variance=4.9716689904776
#
# Add data point: 1.9535172287361462
# Mean=2.9941208833075064  Variance=4.977903806758323
#
# Add data point: 2.4767780069666143
# Mean=2.9970769721059587  Variance=4.973439504839963
#
# Add data point: 2.505837485635828
# Mean=2.997254652697977  Variance=4.973423686831715
#
# Add data point: -0.2880024944655677
# Mean=2.9818342403620686  Variance=5.0319512852256025
#
# Add data point: 2.7115034360709283
# Mean=2.998414854044346  Variance=4.972832999769268
#
# Add data point: 5.097221453874039
# Mean=3.011460226523902  Variance=4.996562105459656
#
# Add data point: 2.106065838458404
# Mean=2.9951416621655347  Variance=4.977020629786954
#
# Add data point: 5.001294555231113
# Mean=3.010817808406655  Variance=4.994475708020293
#
# Add data point: 1.6323833368264942
# Mean=2.9926472222410028  Variance=4.9830287543567895
#
# Add data point: 5.7232058079350665
# Mean=3.014562597903396  Variance=5.012775230759043
#
# Add data point: 6.24071154471368
# Mean=3.0172378273654985  Variance=5.029124858234714
#
# Add data point: 0.2701374851940992
# Mean=2.985556282990445  Variance=5.012833616957998
#
# Add data point: 1.909139851841812
# Mean=2.9942586307991674  Variance=4.979808004402025
#
# Add data point: 5.447048146884482
# Mean=3.0128117704025366  Variance=5.005035229548152
#
# Add data point: 5.298858741899018
# Mean=3.011973222614057  Variance=5.001346737003825
#
# Add data point: -0.8568632042375768
# Mean=2.9800162528277845  Variance=5.051032912484637
#
# Add data point: -1.7037676403558626
# Mean=2.975753775049712  Variance=5.088141872570658
#
# Add data point: 3.409776534168161
# Mean=3.002101418123939  Variance=4.975087915959377
#
# Add data point: 1.8827654171580541
# Mean=2.9942998235569287  Variance=4.980727408609474
#
# Add data point: 5.612780630816402
# Mean=3.0132628458417074  Variance=5.009142702643085
#
# Add data point: 1.4824458369045177
# Mean=2.9923355850348714  Variance=4.9862504541781245
#
# Add data point: 4.358266150882244
# Mean=3.0068254580446343  Variance=4.984018263373769
#
# Add data point: 3.741122363292122
# Mean=3.0037056118164607  Variance=4.977620683646155
#
# Add data point: -1.5163167123508066
# Mean=2.97753076262512  Variance=5.076478192269946
#
# Add data point: 2.5668533421560564
# Mean=2.997855709614634  Variance=4.97605317032332
#
# Add data point: 2.7634509077099647
# Mean=2.998834733535517  Variance=4.975523167476925
#
# Add data point: 3.7991093596888468
# Mean=3.003917202743573  Variance=4.978499731504267
#
# Add data point: 2.190443093327458
# Mean=2.9960509419186705  Variance=4.978687183323022
#
# Add data point: 5.8181935634251465
# Mean=3.013680551278763  Variance=5.014164197655478
#
# Add data point: 1.8655637525814135
# Mean=2.9945196316549825  Variance=4.9819452838395994
#
# Add data point: 4.949881839423801
# Mean=3.009374431920307  Variance=4.99412444518434
#
# Add data point: 0.66360706810539
# Mean=2.988821086450265  Variance=5.0020798730654
#
# Add data point: -1.2435607248118048
# Mean=2.9797925679770865  Variance=5.061828019905663
#
# Add data point: 7.805509694845981
# Mean=3.022774927463725  Variance=5.085635610916821
#
# Add data point: 3.9102032913836897
# Mean=3.0042934117518096  Variance=4.9802111950433074
#
# Add data point: 4.153462653602595
# Mean=3.0054153176225475  Variance=4.982661460974627
#
# Add data point: 7.4552805870815195
# Mean=3.020819068163932  Variance=5.069280611828138
#
# Add data point: 5.357284035195545
# Mean=3.010964111791607  Variance=5.002481039705146
#
# Add data point: 2.2196830904849074
# Mean=2.996387421715208  Variance=4.979563141969082
#
# Add data point: 3.3550280445217324
# Mean=3.0016360739378882  Variance=4.977432703982713
#
# Add data point: 1.5699977053950456
# Mean=2.9934403564467664  Variance=4.986338830678537
#
# Add data point: 5.255047557627865
# Mean=3.010297020811086  Variance=5.000284491814369
#
# Add data point: 5.196292539691354
# Mean=3.009983147907688  Variance=4.99909486304398
#
# Add data point: 2.411111002817471
# Mean=2.9973353439041515  Variance=4.978841913928848
#
# Add data point: 3.344092569079022
# Mean=3.001549966527383  Variance=4.9779088975752535
#
# Add data point: -0.7681052575395952
# Mean=2.983102667006549  Variance=5.041148406768498
#
# Add data point: 0.5097740672714588
# Mean=2.988882919943176  Variance=5.005262516390045
#
# Add data point: 3.028061408949471
# Mean=3.000124717373109  Variance=4.977682071173781
#
# Add data point: 0.9133691490471865
# Mean=2.9907671201285275  Variance=4.997043389760734
#
# Add data point: 5.623473660119609
# Mean=3.0115571526877516  Variance=5.008195991856987
#
# Add data point: 5.786538241100194
# Mean=3.012221658952194  Variance=5.012029688321911
#
# Add data point: -2.6955766700406194
# Mean=2.9751284861570277  Variance=5.119727789431221
#
# Add data point: 1.107590034025001
# Mean=2.991772130582717  Variance=4.993736440948635
#
# Add data point: 1.2724887039604074
# Mean=2.9925215961210405  Variance=4.991179896742466
#
# Add data point: 0.811666496937792
# Mean=2.9905675280040422  Variance=4.99899637284043
#
# Add data point: 1.496786713425335
# Mean=2.9935484408301516  Variance=4.988146345325308
#
# Add data point: 2.395556204592082
# Mean=2.997416906857231  Variance=4.980102107155297
#
# Add data point: 4.442287346992222
# Mean=3.0061373929659245  Variance=4.987484362850751
#
# Add data point: 5.198655266351535
# Mean=3.009316335874371  Variance=4.999206815188605
#
# Add data point: 1.5197957019793438
# Mean=2.9937544122446385  Variance=4.988058305161185
#
# Add data point: 3.050546897199497
# Mean=3.0002123819210063  Variance=4.978913688833626
#
# Add data point: 8.434234402362437
# Mean=3.022737382436663  Variance=5.10255186249564
#
# Add data point: 6.295566880958543
# Mean=3.0137315286706605  Variance=5.024332669019912
#
# Add data point: 2.375035141412751
# Mean=2.99740678481914  Variance=4.980787335025459
#
# Add data point: 1.3069482229579295
# Mean=2.9930039182766857  Variance=4.991097840627184
#
# Add data point: 6.430318046277617
# Mean=3.0141165351698667  Variance=5.027763048319313
#
# Add data point: -0.7127043273665508
# Mean=2.984783998658334  Variance=5.035916382339177
#
# Add data point: 1.689374373696153
# Mean=2.9946505076477394  Variance=4.986519378485901
#
# Add data point: 3.0573092458765783
# Mean=3.0002329644141326  Variance=4.979605187749584
#
# Add data point: 4.010198526818369
# Mean=3.004089872578212  Variance=4.983806380001352
#
# Add data point: -1.8733107098053727
# Mean=2.9803495535894946  Variance=5.0755198159650154
#
# Add data point: 7.106017712944025
# Mean=3.016490030975679  Variance=5.047547068950552
#
# Add data point: 6.939340617896672
# Mean=3.0157573624715868  Variance=5.0419932967301015
#
# Add data point: -1.620530188057974
# Mean=2.981591513194988  Variance=5.065056968999024
#
# Add data point: 4.388352854249013
# Mean=3.00550933672321  Variance=4.987728584639588
#
# Add data point: 2.0361865934056933
# Mean=2.9961904608435006  Variance=4.9838304150707105
#
# Add data point: 5.5760803539106565
# Mean=3.0101420486374435  Variance=5.006363886393522
#
# Add data point: 7.956267020592492
# Mean=3.0194363412572254  Variance=5.076646657804089
#
# Add data point: 4.297607926602285
# Mean=3.00506878096329  Variance=4.986969447218922
#
# Add data point: 4.81846982738602
# Mean=3.007075758083214  Variance=4.993335802580208
#
# Add data point: 2.415065493701424
# Mean=2.997732811991091  Variance=4.98187090358039
#
# Add data point: -0.8035975564149673
# Mean=2.985314295148977  Variance=5.036478666124342
#
# Add data point: 2.390388664562076
# Mean=2.9976553410175466  Variance=4.982124311388421
#
# Add data point: 4.5858347421048204
# Mean=3.006075995180478  Variance=4.990404755019295
#
# Add data point: 0.8469402989371502
# Mean=2.9917822148814395  Variance=4.9985362938481614
#
# Add data point: 1.0248568058981538
# Mean=2.9924899498323123  Variance=4.995749455010422
#
# Add data point: 3.0129487829160606
# Mean=3.0000490484201365  Variance=4.980989228273238
#
# Add data point: 4.1958717898907505
# Mean=3.004512723735437  Variance=4.986457245071386
#
# Add data point: 0.4681892352788193
# Mean=2.9904819144183414  Variance=5.005230067006878
#
# Add data point: -0.0826115323586829
# Mean=2.9884546384555857  Variance=5.01679287216086
#
# Add data point: 1.772745829538247
# Mean=2.9954206933937995  Variance=4.986893381369983
#
# Add data point: 4.780604823768826
# Mean=3.0066193487872446  Variance=4.993129727962866
#
# Add data point: 4.080012868177713
# Mean=3.0040000476599173  Variance=4.985732742351239
#
# Add data point: -1.0361703428567433
# Mean=2.9851063824986834  Variance=5.0415946587381475
#
# Add data point: 6.766998525879573
# Mean=3.0138492592863217  Variance=5.033719954814253
#
# Add data point: 6.714256340895162
# Mean=3.0136053345820337  Variance=5.032151347300141
#
# Add data point: 1.1402560190425075
# Mean=2.9932126132081844  Variance=4.994307783417491
#
# Add data point: 2.3941045808334653
# Mean=2.9977967439303037  Variance=4.983086767577398
#
# Add data point: 1.8762230263823345
# Mean=2.9959283442984868  Variance=4.986393814740041
#
# Add data point: 7.842890411929809
# Mean=3.017483358887833  Variance=5.06655404909723
#
# Add data point: 2.7216517902349886
# Mean=2.9989987474468887  Variance=4.982228155339436
#
# Add data point: 7.8920083510341055
# Mean=3.017534080111233  Variance=5.067791254821063
#
# Add data point: 2.981732130224742
# Mean=2.9999347576079454  Variance=4.982080044886117
#
# Add data point: 0.029470485716376338
# Mean=2.989428720589738  Variance=5.0135451546347785
#
# Add data point: 1.19376263607787
# Mean=2.9935949029648152  Variance=4.993775531278448
#
# Add data point: 3.1104615722847133
# Mean=3.000390323576978  Variance=4.982312619302112
#
# Add data point: -0.8463538912413564
# Mean=2.986456500382953  Variance=5.034425247930086
#
# Add data point: 2.0426706162881656
# Mean=2.9966409495308355  Variance=4.985610083912685
#
# Add data point: 1.7859562136571447
# Mean=2.995755091656144  Variance=4.987609644949331
#
# Add data point: -3.0259619211727466
# Mean=2.9790036169993983  Variance=5.109040886961468
#
# Add data point: 4.785162394762508
# Mean=3.00619848053737  Variance=4.993643691572524
#
# Add data point: 1.417987741457406
# Mean=2.994525909139991  Variance=4.991298967733799
#
# Add data point: -0.2566752041521032
# Mean=2.988770085502924  Variance=5.019271146025092
#
# Add data point: 4.3403701982596905
# Mean=3.0046060831555317  Variance=4.988932477282035
#
# Add data point: 5.639162372551235
# Mean=3.009038227303258  Variance=5.006671218829131
#
# Add data point: 0.7890306327012739
# Mean=2.9924540294631443  Variance=4.999560622032293
#
# Add data point: 4.810776947919491
# Mean=3.0061591052650325  Variance=4.994087919417348
#
# Add data point: 6.2040710817231375
# Mean=3.0108612579041463  Variance=5.017793439640724
#
# Add data point: 7.502714716887696
# Mean=3.0152118740435396  Variance=5.051545576584915
#
# Add data point: 6.8246796634453
# Mean=3.01287770930453  Variance=5.032361220996902
#
# Add data point: 0.11833080636287363
# Mean=2.9903299691488687  Variance=5.011030813170209
#
# Add data point: 4.041805086571303
# Mean=3.003484297948399  Variance=4.986851435835839
#
# Add data point: 1.7978128240788007
# Mean=2.995992709413596  Variance=4.988095105326408
#
# Add data point: 2.9928571311748415
# Mean=2.999976269538787  Variance=4.983333502836905
#
# Add data point: 2.531418593658562
# Mean=2.998448405939267  Variance=4.9841157524459865
#
# Add data point: -1.2771797577813677
# Mean=2.9858838951888402  Variance=5.043820826366283
#
# Add data point: 1.4596032720383
# Mean=2.994932905500126  Variance=4.991303685622862
#
# Add data point: 2.068157960359676
# Mean=2.9969447801979006  Variance=4.986399613830885
#
# Add data point: 5.500286765995315
# Mean=3.0081708717842983  Variance=5.004036079965975
#
# Add data point: 3.431197784080915
# Mean=3.001404553042609  Variance=4.984265770878551
#
# Add data point: 1.1969198689718152
# Mean=2.994145843730428  Variance=4.99426886790246
#
# Add data point: 3.2200337034633444
# Mean=3.000712083182729  Variance=4.983922916066104
#
# Add data point: 1.8383262021848819
# Mean=2.9962526651683383  Variance=4.988171950912118
#
# Add data point: 5.592241629309213
# Mean=3.008335182087811  Variance=5.005477773737831
#
# Add data point: 1.0928075697219928
# Mean=2.993887203749109  Variance=4.995581108319525
#
# Add data point: 3.990823378970018
# Mean=3.0031655699008626  Variance=4.987110879639897
#
# Add data point: 0.10370506664418233
# Mean=2.990776130785491  Variance=5.01074060477735
#
# Add data point: 4.591207468351433
# Mean=3.0050514522804805  Variance=4.992114341715741
#
# Add data point: 1.5699010031985208
# Mean=2.9954743702632864  Variance=4.990599082673353
#
# Add data point: 2.3367556307621884
# Mean=2.997907746469281  Variance=4.985564890563141
#
# Add data point: -0.7235319489756198
# Mean=2.988290780034668  Variance=5.027826783976037
#
# Add data point: 2.423435265158394
# Mean=2.998192587038114  Variance=4.985318820134867
#
# Add data point: 6.347655675211099
# Mean=3.0104614239850345  Variance=5.019347264183068
#
# Add data point: 1.936834958906049
# Mean=2.996687959373539  Variance=4.987896245808736
#
# Add data point: 3.9594735403698773
# Mean=3.002979731491832  Variance=4.98728264953628
#
# Add data point: 2.3913488201863853
# Mean=2.998115631022249  Variance=4.985618973090953
#
# Add data point: 8.375918968852258
# Mean=3.0165923424964576  Variance=5.073719212603409
#
# Add data point: 1.9168118864134966
# Mean=2.996667113496657  Variance=4.988178044278922
#
# Add data point: 6.874321967481801
# Mean=3.0118844232131345  Variance=5.0306594665408815
#
# Add data point: 4.801846005611681
# Mean=3.005510232433063  Variance=4.994591166986623
#
# Add data point: 4.5894754156405355
# Mean=3.0048459616330505  Variance=4.992412017003194
#
# Add data point: 0.32415758061002764
# Mean=2.991866740366596  Variance=5.00651941869595
#
# Add data point: 4.273258318397183
# Mean=3.0038583585405974  Variance=4.989715118718117
#
# Add data point: 2.6418254404879424
# Mean=2.998917901632894  Variance=4.985236064954472
#
# Add data point: 2.8884906678303532
# Mean=2.999664128517561  Variance=4.984931712623432
#
# Add data point: 1.6034882475745642
# Mean=2.9958062710137376  Variance=4.990796350851948
#
# Add data point: 4.818101151315044
# Mean=3.005443416620704  Variance=4.994881667010174
#
# Add data point: 4.238402663683102
# Mean=3.0036967243692034  Variance=4.989607973425485
#
# Add data point: 2.7876935466939163
# Mean=2.9993681355556365  Variance=4.985208775764824
#
# Add data point: 1.0457131244660627
# Mean=2.994200929152718  Variance=4.996452095666181
#
# Add data point: -0.6121203096108339
# Mean=2.9893132535218614  Variance=5.023765018745121
#
# Add data point: 5.314724168903095
# Mean=3.0068280948935193  Variance=5.001012256869309
#
# Add data point: 2.4691095652479818
# Mean=2.998438557544847  Variance=4.9860796923269834
#
# Add data point: 4.689635238069906
# Mean=3.0049549420471258  Variance=4.9936661623324765
#
# Add data point: 2.303156531457339
# Mean=2.997962445998413  Variance=4.9867570995995685
#
# Add data point: 6.745291810239809
# Mean=3.010919218105655  Variance=5.026275775104398
#
# Add data point: 1.663385353855035
# Mean=2.996114492307718  Variance=4.990616167013995
#
# Add data point: 1.5418085842189853
# Mean=2.9957733582151276  Variance=4.991628369047352
#
# Add data point: 6.848443323184137
# Mean=3.011122668564116  Variance=5.028312205948374
#
# Add data point: 2.79448917142295
# Mean=2.999407749773553  Variance=4.985670846782739
#
# Add data point: 3.8386512408049884
# Mean=3.002409917358635  Variance=4.987611858281039
#
# Add data point: 1.67062525789047
# Mean=2.996190903317738  Variance=4.990695900827698
#
# Add data point: 5.27645759618788
# Mean=3.006504164560537  Variance=5.0004798072562195
#
# Add data point: 5.849895054706591
# Mean=3.008119359130218  Variance=5.008853607146881
#
# Add data point: 4.553458845165019
# Mean=3.0044132353555826  Variance=4.992610765253911
#
# Add data point: 2.776937579353978
# Mean=2.9993680951256487  Variance=4.985936408776345
#
# Add data point: 6.444039701682708
# Mean=3.0097289257109683  Variance=5.019342500454288
#
# Add data point: 2.0580638375303884
# Mean=2.9973466586972686  Variance=4.9883749843391065
#
# Add data point: 4.047674473320994
# Mean=3.0029429058239354  Variance=4.988998700266871
#
# Add data point: 4.916689525227663
# Mean=3.005368878221926  Variance=4.996245528829964
#
# Add data point: 6.001993118694502
# Mean=3.0083854556388117  Variance=5.011167477883934
#
# Add data point: 1.1696049650257212
# Mean=2.9949014065878155  Variance=4.995365959620088
#
# Add data point: 7.052702612117192
# Mean=3.011257507255881  Variance=5.031695752460166
#
# Add data point: -0.20872383083786072
# Mean=2.9911115683356293  Variance=5.0146316336113514
#
# Add data point: 5.848134260264374
# Mean=3.0078677741996254  Variance=5.008558061737512
#
# Add data point: 3.6182914698814796
# Mean=3.001703282286175  Variance=4.987240970212209
#
# Add data point: -0.38417926116553147
# Mean=2.9907028042275674  Variance=5.017689272436868
#
# Add data point: 5.236926839024563
# Mean=3.0061285666822593  Variance=4.999972891560033
#
# Add data point: 4.360615931588921
# Mean=3.003717529867729  Variance=4.991359500227205
#
# Add data point: 2.668842801970689
# Mean=2.999097664310547  Variance=4.9866376127728085
#
# Add data point: 2.314315420328867
# Mean=2.998136726685676  Variance=4.987653639577709
#
# Add data point: 2.2689836651931925
# Mean=2.998018925921933  Variance=4.9878612409897904
#
# Add data point: 5.213554935740397
# Mean=3.0059825809074066  Variance=4.9996926359947
#
# Add data point: 2.3020196803843707
# Mean=2.9981186514296074  Variance=4.987799630762958
#
# Add data point: 4.318312315722672
# Mean=3.0035438503110825  Variance=4.991194812561391
#
# Add data point: 4.540699404575687
# Mean=3.004130561406369  Variance=4.992923093284302
#
# Add data point: 6.007788458156879
# Mean=3.0080422151287616  Variance=5.010784456105038
#
# Add data point: 1.6108551430770122
# Mean=2.996295613714872  Variance=4.991776945198822
#
# Add data point: 1.9269843456806186
# Mean=2.9971462349619165  Variance=4.9897288012262795
#
# Add data point: 7.4875818063080795
# Mean=3.0119034000167324  Variance=5.04011960900787
#
# Add data point: -1.8109063405631423
# Mean=2.9872727345487746  Variance=5.047967082587833
#
# Add data point: 2.5567243574701544
# Mean=2.998830407275647  Variance=4.987290938738872
#
# Add data point: 2.3465585894275787
# Mean=2.998280417340599  Variance=4.987931034381352
#
# Add data point: 4.4342830842397545
# Mean=3.003764522530813  Variance=4.992241496249342
#
# Add data point: 1.4151281208962165
# Mean=2.99585112073533  Variance=4.9934520824963196
#
# Add data point: 0.674081656716151
# Mean=2.993927106153306  Variance=5.0010360499592394
#
# Add data point: 5.3523410142148995
# Mean=3.006125888057851  Variance=5.001355347439766
#
# Add data point: 1.862485725985054
# Mean=2.997045417470091  Variance=4.9903400464681935
#
# Add data point: 3.666561658626515
# Mean=3.0017268436751983  Variance=4.9881640347973155
#
# Add data point: 0.3825914580439407
# Mean=2.993236670434222  Variance=5.004749028701883
#
# Add data point: 5.4114523609860665
# Mean=3.0062150834046033  Variance=5.002067480908929
#
# Add data point: 2.9228627368726383
# Mean=2.99980170369376  Variance=4.987128698096208
#
# Add data point: 4.052832466729392
# Mean=3.0026995704275112  Variance=4.989988724955288
#
# Add data point: 2.208518280030525
# Mean=2.9979757500768045  Variance=4.988781643990346
#
# Add data point: 1.0106123385641872
# Mean=2.9949250314759293  Variance=4.997308355978795
#
# Add data point: 1.6619596041337297
# Mean=2.9965953170588646  Variance=4.99180050126954
#
# Add data point: 3.777531401532313
# Mean=3.0019734299531278  Variance=4.9888117574468485
#
# Add data point: 0.31073181682267226
# Mean=2.9931917261185386  Variance=5.005618919001822
#
# Add data point: 2.9132367154382646
# Mean=2.9997809007965612  Variance=4.987360781918434
#
# Add data point: 2.858229494835964
# Mean=2.9996428954529875  Variance=4.987424364265763
#
# Add data point: 2.5048220371217984
# Mean=2.998755834264125  Variance=4.988021625016286
#
# Add data point: -1.1131536604602
# Mean=2.989691344209373  Variance=5.02983827122929
#
# Add data point: 5.419453525741966
# Mean=3.006048633814355  Variance=5.002103060087261
#
# Add data point: 5.659343644587234
# Mean=3.006631779662312  Variance=5.0051361810972725
#
# Add data point: 2.970360496075101
# Mean=2.999926269890734  Variance=4.987533357393689
#
# Add data point: 4.050048008739684
# Mean=3.002605578185458  Variance=4.990298171239982
#
# Add data point: 4.04293075173329
# Mean=3.0025815117617163  Variance=4.990285390111437
#
# Add data point: 2.27645732517977
# Mean=2.9982134748769873  Variance=4.988916389542376
#
# Add data point: 5.681431062873813
# Mean=3.006604510007078  Variance=5.005363859275695
#
# Add data point: 3.035244834875879
# Mean=3.0000865966458865  Variance=4.987687781148524
#
# Add data point: 0.7203582092365055
# Mean=2.9944126426696975  Variance=5.000452160985074
#
# Add data point: 5.28003787168482
# Mean=3.0055746647229458  Variance=5.000455544729477

# %% [markdown]
# ## 3. Baysian Linear regression

# %%
b = 1    # prior gaussian distribution's variance

n = 4    # 1, x, x^2, x^3
a = 1    # variance of e~N(0,a)
w = np.array([1, 2, 3, 4]) #line parameters

# %%
# 矩陣相乘
def matrixMul(A, B):
    return A.dot(B)

# %%
# 畫圖資訊
plot_x         = []
plot_y         = []
plot_mean      = []
plot_variance  = []
converge_times = 10001   # 收斂的次數，最多跑10000次

# %%
# 第一次的iteration時，我們的prior的mean是0，covariance是任意給定的值
prior_mean     = np.zeros((n,1))
prior_variance = (1/b) * np.identity(n)

for i in range(10001):
    x, y = linearmodel_data_generator(n, a, w)   # 新增的點
    print('Add data point ({:.5f}, {:.5f}):'.format(x, y))
    print()
    X = np.array([[x**i for i in range(n)]])
    S = inverse(prior_variance)
    posterior_variance = inverse(a * matrixMul(X.T, X) + S)
    posterior_mean     = matrixMul(posterior_variance, a * X.T * y + matrixMul(S, prior_mean))   # 因為一次只加一點所以y是純數
    
    
    print('Posterior mean:')
    print(posterior_mean)
    print()
    print('Posterior variance:')
    print(posterior_variance)
    print()
    
    
    # marginal後的高斯分佈
    G_mean     = matrixMul(X, posterior_mean)[0][0] 
    G_variance = 1/a + matrixMul(matrixMul(X, posterior_variance), X.T)[0][0]
    print('Predictive distribution ~ N({:.5f},{:.5f})'.format(G_mean, G_variance))
    print('--------------------------------------------------')
    

    # 自定義收斂: sum(|前驗mean-後驗mean|) < 1e-5 or sum(|前驗var-後驗var|) <1e-5
    if abs(prior_mean - posterior_mean).sum() < 1e-5 or abs(prior_variance - posterior_variance).sum() < 1e-5:
        converge_times = i  # 紀錄收斂時迭代次數
        plot_variance.append(posterior_variance)
        plot_mean.append(posterior_mean)
        break
        
    else:
        # 存畫圖資訊: 點(plot_x, plot_y)、高斯分佈的mean&variance
        plot_x.append(x)
        plot_y.append(y)
        if i == 10 or i == 50:
            plot_variance.append(posterior_variance)
            plot_mean.append(posterior_mean)
        
        # 後驗=先驗
        prior_variance = posterior_variance
        prior_mean     = posterior_mean
# Out:
# Add data point (0.35649, 2.16900):
#
# Posterior mean:
# [[1.01105225]
#  [0.360429  ]
#  [0.12848897]
#  [0.0458049 ]]
#
# Posterior variance:
# [[ 0.53386197 -0.16617308 -0.05923887 -0.02111801]
#  [-0.16617308  0.94076113 -0.02111801 -0.00752834]
#  [-0.05923887 -0.02111801  0.99247166 -0.00268377]
#  [-0.02111801 -0.00752834 -0.00268377  0.99904327]]
#
# Predictive distribution ~ N(1.15795,1.53386)
# --------------------------------------------------
# Add data point (-0.58984, 0.22957):
#
# Posterior mean:
# [[0.84153204]
#  [0.56058977]
#  [0.0461371 ]
#  [0.10710924]]
#
# Posterior variance:
# [[ 0.36113922  0.03776909 -0.14314652  0.04134448]
#  [ 0.03776909  0.69995668  0.07795584 -0.08128084]
#  [-0.14314652  0.07795584  0.95170984  0.02766012]
#  [ 0.04134448 -0.08128084  0.02766012  0.97645468]]
#
# Predictive distribution ~ N(0.50495,1.54422)
# --------------------------------------------------
# Add data point (0.73114, 3.65292):
#
# Posterior mean:
# [[1.20374506]
#  [1.17764351]
#  [0.5241804 ]
#  [0.52441144]]
#
# Posterior variance:
# [[ 0.3101978  -0.04901299 -0.21037825 -0.01734465]
#  [-0.04901299  0.5521177  -0.03657783 -0.18126165]
#  [-0.21037825 -0.03657783  0.86297842 -0.04979691]
#  [-0.01734465 -0.18126165 -0.04979691  0.90883948]]
#
# Predictive distribution ~ N(2.54993,1.52763)
# --------------------------------------------------
# Add data point (-0.42583, 2.67970):
#
# Posterior mean:
# [[1.60579201]
#  [0.79950793]
#  [0.47708402]
#  [0.4979518 ]]
#
# Posterior variance:
# [[ 0.24867198  0.00885364 -0.20317102 -0.01329549]
#  [ 0.00885364  0.49769264 -0.04335642 -0.18506998]
#  [-0.20317102 -0.04335642  0.86213415 -0.05027124]
#  [-0.01329549 -0.18506998 -0.05027124  0.908573  ]]
#
# Predictive distribution ~ N(1.31340,1.28945)
# --------------------------------------------------
# Add data point (-0.07742, 1.03602):
#
# Posterior mean:
# [[1.50484021]
#  [0.81172027]
#  [0.55670136]
#  [0.49782497]]
#
# Posterior variance:
# [[ 0.1998725   0.01475701 -0.16468449 -0.0133568 ]
#  [ 0.01475701  0.49697849 -0.0480122  -0.18506257]
#  [-0.16468449 -0.0480122   0.8317811  -0.05022288]
#  [-0.0133568  -0.18506257 -0.05022288  0.90857292]]
#
# Predictive distribution ~ N(1.44510,1.19867)
# --------------------------------------------------
# Add data point (0.47861, 3.66392):
#
# Posterior mean:
# [[1.71439443]
#  [1.08821249]
#  [0.5534121 ]
#  [0.480558  ]]
#
# Posterior variance:
# [[ 0.17774305 -0.01444125 -0.16433713 -0.01153337]
#  [-0.01444125  0.45845342 -0.0475539  -0.18265667]
#  [-0.16433713 -0.0475539   0.83177565 -0.0502515 ]
#  [-0.01153337 -0.18265667 -0.0502515   0.90842267]]
#
# Predictive distribution ~ N(2.41469,1.21356)
# --------------------------------------------------
# Add data point (0.47864, 1.59280):
#
# Posterior mean:
# [[1.6250479 ]
#  [0.97031501]
#  [0.55479967]
#  [0.48791212]]
#
# Posterior variance:
# [[ 0.16340365 -0.03336285 -0.16411444 -0.01035309]
#  [-0.03336285  0.43348536 -0.04726004 -0.18109924]
#  [-0.16411444 -0.04726004  0.83177219 -0.05026983]
#  [-0.01035309 -0.18109924 -0.05026983  0.90832553]]
#
# Predictive distribution ~ N(2.27009,1.17599)
# --------------------------------------------------
# Add data point (0.55507, 4.74329):
#
# Posterior mean:
# [[1.80364964]
#  [1.28240004]
#  [0.66543105]
#  [0.54383206]]
#
# Posterior variance:
# [[ 0.15629498 -0.04578441 -0.16851777 -0.01257881]
#  [-0.04578441  0.41178019 -0.05495433 -0.18498841]
#  [-0.16851777 -0.05495433  0.82904463 -0.05164851]
#  [-0.01257881 -0.18498841 -0.05164851  0.90762866]]
#
# Predictive distribution ~ N(2.81350,1.17008)
# --------------------------------------------------
# Add data point (0.95742, 8.28892):
#
# Posterior mean:
# [[1.69414306]
#  [1.56258482]
#  [1.68406174]
#  [1.6987673 ]]
#
# Posterior variance:
# [[ 0.15490189 -0.04222004 -0.15555926  0.0021137 ]
#  [-0.04222004  0.40266035 -0.08811013 -0.22258083]
#  [-0.15555926 -0.08811013  0.7085045  -0.1883183 ]
#  [ 0.0021137  -0.22258083 -0.1883183   0.75267087]]
#
# Predictive distribution ~ N(6.22477,1.50503)
# --------------------------------------------------
# Add data point (0.94768, 10.55529):
#
# Posterior mean:
# [[1.62539228]
#  [1.77406902]
#  [2.39187334]
#  [2.48330315]]
#
# Posterior variance:
# [[ 0.15454404 -0.04111926 -0.1518751   0.00619721]
#  [-0.04111926  0.39927425 -0.09944298 -0.23514212]
#  [-0.1518751  -0.09944298  0.67057485 -0.23035939]
#  [ 0.00619721 -0.23514212 -0.23035939  0.70607267]]
#
# Predictive distribution ~ N(7.56831,1.32453)
# --------------------------------------------------
# Add data point (0.63586, 2.99185):
#
# Posterior mean:
# [[1.54200635]
#  [1.63777433]
#  [2.39577091]
#  [2.5500932 ]]
#
# Posterior variance:
# [[ 0.15036062 -0.04795708 -0.15167956  0.00954803]
#  [-0.04795708  0.38809781 -0.09912337 -0.2296652 ]
#  [-0.15167956 -0.09912337  0.67056571 -0.23051602]
#  [ 0.00954803 -0.2296652  -0.23051602  0.70338876]]
#
# Predictive distribution ~ N(4.20764,1.11068)
# --------------------------------------------------
# Add data point (0.24246, 3.08424):
#
# Posterior mean:
# [[1.6533199 ]
#  [1.66950274]
#  [2.27621215]
#  [2.50755348]]
#
# Posterior variance:
# [[ 0.13541617 -0.05221679 -0.13562814  0.01525922]
#  [-0.05221679  0.38688364 -0.09454813 -0.2280373 ]
#  [-0.13562814 -0.09454813  0.65332532 -0.23665025]
#  [ 0.01525922 -0.2280373  -0.23665025  0.70120616]]
#
# Predictive distribution ~ N(2.22767,1.11506)
# --------------------------------------------------
# Add data point (0.16807, 2.50189):
#
# Posterior mean:
# [[1.70725253]
#  [1.67347592]
#  [2.21731725]
#  [2.49595679]]
#
# Posterior variance:
# [[ 0.12193999 -0.05320957 -0.12091203  0.01815689]
#  [-0.05320957  0.3868105  -0.093464   -0.22782383]
#  [-0.12091203 -0.093464    0.63725521 -0.23981453]
#  [ 0.01815689 -0.22782383 -0.23981453  0.7005831 ]]
#
# Predictive distribution ~ N(2.06299,1.10753)
# --------------------------------------------------
# Add data point (-0.57455, -0.97715):
#
# Posterior mean:
# [[1.54518523]
#  [2.06411051]
#  [1.9372359 ]
#  [2.58947936]]
#
# Posterior variance:
# [[ 0.11301214 -0.03169057 -0.13634095  0.02330879]
#  [-0.03169057  0.33494275 -0.05627531 -0.24024159]
#  [-0.13634095 -0.05627531  0.61059127 -0.23091111]
#  [ 0.02330879 -0.24024159 -0.23091111  0.69761014]]
#
# Predictive distribution ~ N(0.50761,1.25067)
# --------------------------------------------------
# Add data point (0.84060, 7.45049):
#
# Posterior mean:
# [[1.54933035]
#  [2.13615413]
#  [2.05550761]
#  [2.66704096]]
#
# Posterior variance:
# [[ 0.11299941 -0.03191173 -0.13670403  0.02307069]
#  [-0.03191173  0.3310989  -0.06258564 -0.24437985]
#  [-0.13670403 -0.06258564  0.60023181 -0.23770476]
#  [ 0.02307069 -0.24437985 -0.23770476  0.69315492]]
#
# Predictive distribution ~ N(6.38159,1.15385)
# --------------------------------------------------
# Add data point (-0.69552, 0.23608):
#
# Posterior mean:
# [[1.55264999]
#  [2.12476864]
#  [2.07051658]
#  [2.65863855]]
#
# Posterior variance:
# [[ 0.11030325 -0.02266461 -0.14889407  0.029895  ]
#  [-0.02266461  0.29938377 -0.02077705 -0.2677854 ]
#  [-0.14889407 -0.02077705  0.54511749 -0.20685031]
#  [ 0.029895   -0.2677854  -0.20685031  0.67588178]]
#
# Predictive distribution ~ N(0.18193,1.28255)
# --------------------------------------------------
# Add data point (-0.73036, -2.26984):
#
# Posterior mean:
# [[1.4896329 ]
#  [2.38552858]
#  [1.65202716]
#  [2.91958443]]
#
# Posterior variance:
# [[ 0.10933925 -0.01867566 -0.15529589  0.03388681]
#  [-0.01867566  0.28287777  0.00571317 -0.28430317]
#  [-0.15529589  0.00571317  0.50260376 -0.1803412 ]
#  [ 0.03388681 -0.28430317 -0.1803412   0.65935223]]
#
# Predictive distribution ~ N(-0.50888,1.24723)
# --------------------------------------------------
# Add data point (-0.79545, -0.56326):
#
# Posterior mean:
# [[1.49141784]
#  [2.36603083]
#  [1.70207464]
#  [2.88220497]]
#
# Posterior variance:
# [[ 0.1092803  -0.01803168 -0.15694885  0.03512137]
#  [-0.01803168  0.27584338  0.02376927 -0.29778891]
#  [-0.15694885  0.02376927  0.45625677 -0.14572556]
#  [ 0.03512137 -0.29778891 -0.14572556  0.6334985 ]]
#
# Predictive distribution ~ N(-0.76430,1.25212)
# --------------------------------------------------
# Add data point (-0.07495, -0.45994):
#
# Posterior mean:
# [[1.31548361]
#  [2.42767233]
#  [1.95235301]
#  [2.79185217]]
#
# Posterior variance:
# [[ 0.09844854 -0.0142366  -0.14153995  0.02955862]
#  [-0.0142366   0.27451371  0.0183705  -0.29583991]
#  [-0.14153995  0.0183705   0.43433656 -0.13781216]
#  [ 0.02955862 -0.29583991 -0.13781216  0.63064169]]
#
# Predictive distribution ~ N(1.14332,1.10049)
# --------------------------------------------------
# Add data point (0.93057, 9.67058):
#
# Posterior mean:
# [[1.29195116]
#  [2.46020316]
#  [2.19660738]
#  [3.04043619]]
#
# Posterior variance:
# [[ 0.09830064 -0.01403214 -0.14000482  0.03112096]
#  [-0.01403214  0.27423107  0.01624836 -0.29799966]
#  [-0.14000482  0.01624836  0.4184027  -0.15402846]
#  [ 0.03112096 -0.29799966 -0.15402846  0.61413795]]
#
# Predictive distribution ~ N(7.93358,1.19418)
# --------------------------------------------------
# Add data point (-0.12532, 2.17334):
#
# Posterior mean:
# [[1.39504894]
#  [2.41006937]
#  [2.05411733]
#  [3.1087877 ]]
#
# Posterior variance:
# [[ 0.0896174  -0.00980971 -0.12800383  0.02536417]
#  [-0.00980971  0.27217781  0.01041259 -0.29520028]
#  [-0.12800383  0.01041259  0.4018163  -0.14607207]
#  [ 0.02536417 -0.29520028 -0.14607207  0.61032132]]
#
# Predictive distribution ~ N(1.11916,1.09215)
# --------------------------------------------------
# Add data point (-0.51973, -0.88703):
#
# Posterior mean:
# [[1.33619234]
#  [2.52139091]
#  [2.05866382]
#  [3.05297832]]
#
# Posterior variance:
# [[ 0.08671645 -0.00432285 -0.12777974  0.02261341]
#  [-0.00432285  0.26179995  0.00998875 -0.2899975 ]
#  [-0.12777974  0.00998875  0.40179899 -0.14585958]
#  [ 0.02261341 -0.2899975  -0.14585958  0.60771298]]
#
# Predictive distribution ~ N(0.15323,1.09378)
# --------------------------------------------------
# Add data point (0.58223, 5.41887):
#
# Posterior mean:
# [[1.39135332]
#  [2.63604547]
#  [2.04097092]
#  [2.96085519]]
#
# Posterior variance:
# [[ 0.08481311 -0.00827902 -0.12716924  0.02579214]
#  [-0.00827902  0.25357685  0.01125769 -0.28339037]
#  [-0.12716924  0.01125769  0.40160317 -0.14687916]
#  [ 0.02579214 -0.28339037 -0.14687916  0.60240426]]
#
# Predictive distribution ~ N(4.20243,1.07437)
# --------------------------------------------------
# Add data point (0.33666, 0.72717):
#
# Posterior mean:
# [[1.27087183]
#  [2.51739597]
#  [2.18756772]
#  [3.07199204]]
#
# Posterior variance:
# [[ 0.08045404 -0.01257182 -0.1218653   0.02981312]
#  [-0.01257182  0.24934934  0.01648098 -0.27943053]
#  [-0.1218653   0.01648098  0.39514956 -0.15177172]
#  [ 0.02981312 -0.27943053 -0.15177172  0.59869515]]
#
# Predictive distribution ~ N(2.48355,1.07361)
# --------------------------------------------------
# Add data point (-0.70306, 0.70870):
#
# Posterior mean:
# [[1.29022792]
#  [2.43184685]
#  [2.3062355 ]
#  [3.01317279]]
#
# Posterior variance:
# [[ 0.08015097 -0.01123235 -0.12372332  0.03073407]
#  [-0.01123235  0.24342922  0.02469296 -0.28350091]
#  [-0.12372332  0.02469296  0.38375848 -0.14612558]
#  [ 0.03073407 -0.28350091 -0.14612558  0.59589657]]
#
# Predictive distribution ~ N(-0.32669,1.13283)
# --------------------------------------------------
# Add data point (-0.44298, -0.45785):
#
# Posterior mean:
# [[1.24391502]
#  [2.50315755]
#  [2.3433749 ]
#  [2.9527942 ]]
#
# Posterior variance:
# [[ 0.0770233  -0.00641649 -0.12121517  0.02665649]
#  [-0.00641649  0.23601395  0.02083101 -0.27722242]
#  [-0.12121517  0.02083101  0.38174713 -0.14285568]
#  [ 0.02665649 -0.27722242 -0.14285568  0.59058059]]
#
# Predictive distribution ~ N(0.33823,1.07588)
# --------------------------------------------------
# Add data point (0.66869, 3.93634):
#
# Posterior mean:
# [[1.22140844]
#  [2.43706411]
#  [2.32579992]
#  [2.99186951]]
#
# Posterior variance:
# [[ 0.07636933 -0.00833696 -0.12172584  0.0277919 ]
#  [-0.00833696  0.23037424  0.01933135 -0.27388815]
#  [-0.12172584  0.01933135  0.38134836 -0.14196906]
#  [ 0.0277919  -0.27388815 -0.14196906  0.58860933]]
#
# Predictive distribution ~ N(4.78556,1.06894)
# --------------------------------------------------
# Add data point (-0.25269, -0.14765):
#
# Posterior mean:
# [[1.16578632]
#  [2.48527775]
#  [2.4049475 ]
#  [2.92976794]]
#
# Posterior variance:
# [[ 0.07179069 -0.00436816 -0.11521066  0.02267989]
#  [-0.00436816  0.22693406  0.01368394 -0.26945703]
#  [-0.11521066  0.01368394  0.37207757 -0.13469492]
#  [ 0.02267989 -0.26945703 -0.13469492  0.58290182]]
#
# Predictive distribution ~ N(0.64406,1.07235)
# --------------------------------------------------
# Add data point (0.60340, 4.34850):
#
# Posterior mean:
# [[1.17073456]
#  [2.49732134]
#  [2.40478231]
#  [2.92040767]]
#
# Posterior variance:
# [[ 0.07081836 -0.00673473 -0.1151782   0.02451919]
#  [-0.00673473  0.22117403  0.01376295 -0.26498033]
#  [-0.1151782   0.01376295  0.37207648 -0.13475632]
#  [ 0.02451919 -0.26498033 -0.13475632  0.57942253]]
#
# Predictive distribution ~ N(4.19478,1.06165)
# --------------------------------------------------
# Add data point (-0.19116, -0.13855):
#
# Posterior mean:
# [[1.11393717]
#  [2.53645322]
#  [2.49138948]
#  [2.86488833]]
#
# Posterior variance:
# [[ 0.06654131 -0.00378796 -0.10865637  0.02033838]
#  [-0.00378796  0.21914379  0.00926958 -0.26209987]
#  [-0.10865637  0.00926958  0.36213171 -0.12838125]
#  [ 0.02033838 -0.26209987 -0.12838125  0.57533581]]
#
# Predictive distribution ~ N(0.70009,1.06752)
# --------------------------------------------------
# Add data point (-0.10147, -0.27100):
#
# Posterior mean:
# [[1.04303807]
#  [2.56410335]
#  [2.60534215]
#  [2.81637814]]
#
# Posterior variance:
# [[ 0.06248628 -0.00220652 -0.10213891  0.01756387]
#  [-0.00220652  0.21852704  0.00672782 -0.26101783]
#  [-0.10213891  0.00672782  0.35165651 -0.12392191]
#  [ 0.01756387 -0.26101783 -0.12392191  0.57343744]]
#
# Predictive distribution ~ N(0.80673,1.06302)
# --------------------------------------------------
# Add data point (0.48382, 3.74207):
#
# Posterior mean:
# [[1.06276252]
#  [2.6018228 ]
#  [2.59006046]
#  [2.78003144]]
#
# Posterior variance:
# [[ 0.0610153  -0.00501951 -0.10099925  0.02027448]
#  [-0.00501951  0.21314771  0.0089072  -0.25583428]
#  [-0.10099925  0.0089072   0.35077356 -0.12602197]
#  [ 0.02027448 -0.25583428 -0.12602197  0.56844254]]
#
# Predictive distribution ~ N(3.24271,1.05717)
# --------------------------------------------------
# Add data point (-0.99902, -2.66655):
#
# Posterior mean:
# [[1.09363938]
#  [2.57598487]
#  [2.38462658]
#  [3.01401835]]
#
# Posterior variance:
# [[ 0.05921524 -0.00351322 -0.08902291  0.00663356]
#  [-0.00351322  0.21188723 -0.00111467 -0.24441948]
#  [-0.08902291 -0.00111467  0.27109103 -0.03526446]
#  [ 0.00663356 -0.24441948 -0.03526446  0.46507074]]
#
# Predictive distribution ~ N(-2.10501,1.40463)
# --------------------------------------------------
# Add data point (0.82347, 6.92652):
#
# Posterior mean:
# [[1.0935119 ]
#  [2.58859515]
#  [2.41236657]
#  [3.02940155]]
#
# Posterior variance:
# [[ 0.05921514 -0.00350277 -0.08899993  0.00664631]
#  [-0.00350277  0.21085368 -0.00338826 -0.2456803 ]
#  [-0.08899993 -0.00338826  0.26608959 -0.038038  ]
#  [ 0.00664631 -0.2456803  -0.038038    0.46353268]]
#
# Predictive distribution ~ N(6.55265,1.09151)
# --------------------------------------------------
# Add data point (-0.49998, 0.27164):
#
# Posterior mean:
# [[1.10232808]
#  [2.57019683]
#  [2.40863565]
#  [3.04383742]]
#
# Posterior variance:
# [[ 0.05786814 -0.00069174 -0.08842989  0.00444069]
#  [-0.00069174  0.20498739 -0.00457786 -0.24107743]
#  [-0.08842989 -0.00457786  0.26584836 -0.03710461]
#  [ 0.00444069 -0.24107743 -0.03710461  0.45992113]]
#
# Predictive distribution ~ N(0.03895,1.06161)
# --------------------------------------------------
# Add data point (-0.40784, 0.41737):
#
# Posterior mean:
# [[1.10921031]
#  [2.55923674]
#  [2.40228213]
#  [3.05426926]]
#
# Posterior variance:
# [[ 0.05611258  0.00210402 -0.0868092   0.00177968]
#  [ 0.00210402  0.2005351  -0.00715884 -0.23683973]
#  [-0.0868092  -0.00715884  0.26435218 -0.03464803]
#  [ 0.00177968 -0.23683973 -0.03464803  0.45588767]]
#
# Predictive distribution ~ N(0.25783,1.05669)
# --------------------------------------------------
# Add data point (-0.49587, -1.58695):
#
# Posterior mean:
# [[1.0571085 ]
#  [2.66842385]
#  [2.42410299]
#  [2.96856576]]
#
# Posterior variance:
# [[ 5.50515859e-02  4.32749628e-03 -8.63648462e-02  3.44261309e-05]
#  [ 4.32749628e-03  1.95875468e-01 -8.09005579e-03 -2.33182278e-01]
#  [-8.63648462e-02 -8.09005579e-03  2.64166078e-01 -3.39170940e-02]
#  [ 3.44261309e-05 -2.33182278e-01 -3.39170940e-02  4.53016858e-01]]
#
# Predictive distribution ~ N(-0.03199,1.05496)
# --------------------------------------------------
# Add data point (-0.73926, -1.30599):
#
# Posterior mean:
# [[1.0549251 ]
#  [2.69227638]
#  [2.38754677]
#  [2.98227852]]
#
# Posterior variance:
# [[ 5.50319485e-02  4.54202418e-03 -8.66936302e-02  1.57757670e-04]
#  [ 4.54202418e-03  1.93531862e-01 -4.49826181e-03 -2.34529611e-01]
#  [-8.66936302e-02 -4.49826181e-03  2.58661320e-01 -3.18521808e-02]
#  [ 1.57757670e-04 -2.34529611e-01 -3.18521808e-02  4.52242279e-01]]
#
# Predictive distribution ~ N(-0.83542,1.08788)
# --------------------------------------------------
# Add data point (-0.74041, -1.28778):
#
# Posterior mean:
# [[1.053247  ]
#  [2.71120834]
#  [2.35819018]
#  [2.99347504]]
#
# Posterior variance:
# [[ 5.50166579e-02  4.71452992e-03 -8.69611239e-02  2.59778969e-04]
#  [ 4.71452992e-03  1.91585691e-01 -1.48045780e-03 -2.35680592e-01]
#  [-8.69611239e-02 -1.48045780e-03  2.53981802e-01 -3.00674269e-02]
#  [ 2.59778969e-04 -2.35680592e-01 -3.00674269e-02  4.51561580e-01]]
#
# Predictive distribution ~ N(-0.87641,1.08116)
# --------------------------------------------------
# Add data point (0.79199, 6.10277):
#
# Posterior mean:
# [[1.05299032]
#  [2.70893159]
#  [2.35485932]
#  [2.99234581]]
#
# Posterior variance:
# [[ 5.49992598e-02  4.56020923e-03 -8.71868934e-02  1.83238931e-04]
#  [ 4.56020923e-03  1.90216866e-01 -3.48303389e-03 -2.36359502e-01]
#  [-8.71868934e-02 -3.48303389e-03  2.51052055e-01 -3.10606654e-02]
#  [ 1.83238931e-04 -2.36359502e-01 -3.10606654e-02  4.51224854e-01]]
#
# Predictive distribution ~ N(6.16200,1.07367)
# --------------------------------------------------
# Add data point (-0.83527, -1.03191):
#
# Posterior mean:
# [[1.05059384]
#  [2.70425482]
#  [2.38166064]
#  [2.97094635]]
#
# Posterior variance:
# [[ 0.05491545  0.00439665 -0.08624959 -0.00056515]
#  [ 0.00439665  0.18989768 -0.00165387 -0.23781999]
#  [-0.08624959 -0.00165387  0.24056961 -0.02269097]
#  [-0.00056515 -0.23781999 -0.02269097  0.44454209]]
#
# Predictive distribution ~ N(-1.27785,1.11729)
# --------------------------------------------------
# Add data point (0.03089, 1.86548):
#
# Posterior mean:
# [[1.08856973]
#  [2.7113384 ]
#  [2.32219698]
#  [2.96547541]]
#
# Posterior variance:
# [[ 5.20519393e-02  3.86252665e-03 -8.17658297e-02 -1.52621684e-04]
#  [ 3.86252665e-03  1.89798052e-01 -8.17522288e-04 -2.37743047e-01]
#  [-8.17658297e-02 -8.17522288e-04  2.33548815e-01 -2.33369194e-02]
#  [-1.52621684e-04 -2.37743047e-01 -2.33369194e-02  4.44482657e-01]]
#
# Predictive distribution ~ N(1.17461,1.05232)
# --------------------------------------------------
# Add data point (0.36097, 1.39388):
#
# Posterior mean:
# [[1.04332249]
#  [2.64673766]
#  [2.37795875]
#  [3.03750044]]
#
# Posterior variance:
# [[ 0.05031642  0.00138468 -0.07962701  0.00260999]
#  [ 0.00138468  0.18626036  0.00223612 -0.23379879]
#  [-0.07962701  0.00223612  0.23091298 -0.02674151]
#  [ 0.00260999 -0.23379879 -0.02674151  0.4400851 ]]
#
# Predictive distribution ~ N(2.45143,1.05192)
# --------------------------------------------------
# Add data point (0.03815, 2.47582):
#
# Posterior mean:
# [[1.10684794]
#  [2.65745889]
#  [2.27783309]
#  [3.02950554]]
#
# Posterior variance:
# [[ 0.04791232  0.00097894 -0.07583779  0.00291256]
#  [ 0.00097894  0.18619189  0.00287563 -0.23374772]
#  [-0.07583779  0.00287563  0.2249406  -0.0272184 ]
#  [ 0.00291256 -0.23374772 -0.0272184   0.44004702]]
#
# Predictive distribution ~ N(1.21172,1.04804)
# --------------------------------------------------
# Add data point (-0.89572, -1.71182):
#
# Posterior mean:
# [[1.1080556 ]
#  [2.65711764]
#  [2.26859773]
#  [3.03905779]]
#
# Posterior variance:
# [[ 0.04769578  0.00104013 -0.07418184  0.00119978]
#  [ 0.00104013  0.1861746   0.00240771 -0.23326374]
#  [-0.07418184  0.00240771  0.21227701 -0.01412028]
#  [ 0.00119978 -0.23326374 -0.01412028  0.42649947]]
#
# Predictive distribution ~ N(-1.63588,1.14387)
# --------------------------------------------------
# Add data point (0.50419, 3.41424):
#
# Posterior mean:
# [[1.10806291]
#  [2.65713391]
#  [2.26859257]
#  [3.03904159]]
#
# Posterior variance:
# [[ 0.04686522 -0.00080643 -0.07359613  0.00303825]
#  [-0.00080643  0.1820692   0.00370989 -0.22917634]
#  [-0.07359613  0.00370989  0.21186397 -0.01541675]
#  [ 0.00303825 -0.22917634 -0.01541675  0.42242999]]
#
# Predictive distribution ~ N(3.41399,1.04665)
# --------------------------------------------------
# Add data point (-0.93154, -4.20266):
#
# Posterior mean:
# [[1.14527897]
#  [2.62118882]
#  [2.03129695]
#  [3.31428101]]
#
# Posterior variance:
# [[ 0.0465687  -0.00052003 -0.07170544  0.00084522]
#  [-0.00052003  0.18179258  0.00188376 -0.22705821]
#  [-0.07170544  0.00188376  0.19980857 -0.00143368]
#  [ 0.00084522 -0.22705821 -0.00143368  0.40621102]]
#
# Predictive distribution ~ N(-2.21290,1.15238)
# --------------------------------------------------
# Add data point (-0.67464, -0.37202):
#
# Posterior mean:
# [[1.14988008]
#  [2.6039358 ]
#  [2.03733467]
#  [3.32367961]]
#
# Posterior variance:
# [[ 4.63812135e-02  1.82989794e-04 -7.19514587e-02  4.62251633e-04]
#  [ 1.82989794e-04  1.79156427e-01  2.80628610e-03 -2.25622167e-01]
#  [-7.19514587e-02  2.80628610e-03  1.99485732e-01 -1.93622922e-03]
#  [ 4.62251633e-04 -2.25622167e-01 -1.93622922e-03  4.05428727e-01]]
#
# Predictive distribution ~ N(-0.70010,1.04679)
# --------------------------------------------------
# Add data point (-0.06734, 0.07062):
#
# Posterior mean:
# [[1.10974993]
#  [2.61422058]
#  [2.09942257]
#  [3.31014959]]
#
# Posterior variance:
# [[ 4.43555190e-02  7.02146587e-04 -6.88173786e-02 -2.20718316e-04]
#  [ 7.02146587e-04  1.79023374e-01  2.00306574e-03 -2.25447131e-01]
#  [-6.88173786e-02  2.00306574e-03  1.94636798e-01 -8.79563148e-04]
#  [-2.20718316e-04 -2.25447131e-01 -8.79563148e-04  4.05198462e-01]]
#
# Predictive distribution ~ N(0.94221,1.04444)
# --------------------------------------------------
# Add data point (0.31479, 2.69317):
#
# Posterior mean:
# [[1.1259476 ]
#  [2.63577004]
#  [2.07842927]
#  [3.28498995]]
#
# Posterior variance:
# [[ 0.04299425 -0.00110889 -0.06705309  0.00189372]
#  [-0.00110889  0.17661397  0.00435029 -0.22263408]
#  [-0.06705309  0.00435029  0.19235016 -0.00362002]
#  [ 0.00189372 -0.22263408 -0.00362002  0.40191414]]
#
# Predictive distribution ~ N(2.26410,1.04478)
# --------------------------------------------------
# Add data point (0.84354, 5.96296):
#
# Posterior mean:
# [[1.129408  ]
#  [2.62248779]
#  [2.02379384]
#  [3.24457038]]
#
# Posterior variance:
# [[ 0.04297558 -0.00103721 -0.06675827  0.00211182]
#  [-0.00103721  0.17633887  0.00321868 -0.22347124]
#  [-0.06675827  0.00321868  0.1876954  -0.00706363]
#  [ 0.00211182 -0.22347124 -0.00706363  0.39936653]]
#
# Predictive distribution ~ N(6.72910,1.08468)
# --------------------------------------------------
# Add data point (-0.59447, 1.16983):
#
# Posterior mean:
# [[1.15875685]
#  [2.53577618]
#  [2.02250635]
#  [3.31744934]]
#
# Posterior variance:
# [[ 4.26090243e-02  4.57873874e-05 -6.67421925e-02  1.20158571e-03]
#  [ 4.57873874e-05  1.73139126e-01  3.17117409e-03 -2.20781939e-01]
#  [-6.67421925e-02  3.17117409e-03  1.87694692e-01 -7.02369801e-03]
#  [ 1.20158571e-03 -2.20781939e-01 -7.02369801e-03  3.97106240e-01]]
#
# Predictive distribution ~ N(-0.33087,1.04159)
# --------------------------------------------------
# Add data point (-0.07297, 1.84185):
#
# Posterior mean:
# [[1.19354609]
#  [2.52549484]
#  [1.96818437]
#  [3.33154724]]
#
# Posterior variance:
# [[ 0.04089725  0.00055167 -0.06406932  0.00050791]
#  [ 0.00055167  0.17298962  0.00238125 -0.22057694]
#  [-0.06406932  0.00238125  0.18352111 -0.00594055]
#  [ 0.00050791 -0.22057694 -0.00594055  0.39682514]]
#
# Predictive distribution ~ N(1.01844,1.04105)
# --------------------------------------------------
# Add data point (-0.82963, -0.13436):
#
# Posterior mean:
# [[1.18873711]
#  [2.50676822]
#  [2.04572922]
#  [3.27408141]]
#
# Posterior variance:
# [[ 4.08828101e-02  4.95450993e-04 -6.38365153e-02  3.35384427e-04]
#  [ 4.95450993e-04  1.72770688e-01  3.28782787e-03 -2.21248765e-01]
#  [-6.38365153e-02  3.28782787e-03  1.79767094e-01 -3.15857618e-03]
#  [ 3.35384427e-04 -2.21248765e-01 -3.15857618e-03  3.94763510e-01]]
#
# Predictive distribution ~ N(-1.35245,1.07370)
# --------------------------------------------------
# Add data point (-0.03340, 0.01480):
#
# Posterior mean:
# [[1.14592454]
#  [2.51229159]
#  [2.11262745]
#  [3.26599353]]
#
# Posterior variance:
# [[ 3.92839667e-02  7.01722230e-04 -6.13381882e-02  3.33412013e-05]
#  [ 7.01722230e-04  1.72744077e-01  2.96551173e-03 -2.21209798e-01]
#  [-6.13381882e-02  2.96551173e-03  1.75863248e-01 -2.68660827e-03]
#  [ 3.33412013e-05 -2.21209798e-01 -2.68660827e-03  3.94706450e-01]]
#
# Predictive distribution ~ N(1.06425,1.03929)
# --------------------------------------------------
# Add data point (-0.12319, 0.98627):
#
# Posterior mean:
# [[1.15048366]
#  [2.50989442]
#  [2.10559462]
#  [3.26915149]]
#
# Posterior variance:
# [[ 0.03787569  0.00144219 -0.05916579 -0.00094213]
#  [ 0.00144219  0.17235474  0.00182327 -0.2206969 ]
#  [-0.05916579  0.00182327  0.17251214 -0.00118186]
#  [-0.00094213 -0.2206969  -0.00118186  0.39403077]]
#
# Predictive distribution ~ N(0.86713,1.03828)
# --------------------------------------------------
# Add data point (0.29985, 1.59926):
#
# Posterior mean:
# [[1.13209143]
#  [2.4834822 ]
#  [2.12966537]
#  [3.30073305]]
#
# Posterior variance:
# [[ 3.68326669e-02 -5.56382118e-05 -5.78007447e-02  8.48854431e-04]
#  [-5.56382118e-05  1.70203772e-01  3.78355166e-03 -2.18124948e-01]
#  [-5.78007447e-02  3.78355166e-03  1.70725636e-01 -3.52580281e-03]
#  [ 8.48854431e-04 -2.18124948e-01 -3.52580281e-03  3.90955447e-01]]
#
# Predictive distribution ~ N(2.15723,1.04008)
# --------------------------------------------------
# Add data point (-0.34012, -0.35992):
#
# Posterior mean:
# [[1.10995961]
#  [2.51941843]
#  [2.15845704]
#  [3.25721538]]
#
# Posterior variance:
# [[ 0.0359596   0.001362   -0.05666495 -0.00086786]
#  [ 0.001362    0.16790191  0.00193933 -0.21533746]
#  [-0.05666495  0.00193933  0.16924806 -0.0012925 ]
#  [-0.00086786 -0.21533746 -0.0012925   0.38757988]]
#
# Predictive distribution ~ N(0.37458,1.03838)
# --------------------------------------------------
# Add data point (-0.04246, 2.04724):
#
# Posterior mean:
# [[1.14592064]
#  [2.5136457 ]
#  [2.10176056]
#  [3.2654955 ]]
#
# Posterior variance:
# [[ 0.03472244  0.00156059 -0.05471445 -0.00115272]
#  [ 0.00156059  0.16787003  0.00162622 -0.21529173]
#  [-0.05471445  0.00162622  0.16617288 -0.00084339]
#  [-0.00115272 -0.21529173 -0.00084339  0.3875143 ]]
#
# Predictive distribution ~ N(1.04273,1.03469)
# --------------------------------------------------
# Add data point (-0.09186, 0.26563):
#
# Posterior mean:
# [[1.12401047]
#  [2.52243007]
#  [2.13609229]
#  [3.25373332]]
#
# Posterior variance:
# [[ 3.35976503e-02  2.01155374e-03 -5.29519735e-02 -1.75654717e-03]
#  [ 2.01155374e-03  1.67689225e-01  9.19593530e-04 -2.15049641e-01]
#  [-5.29519735e-02  9.19593530e-04  1.63411207e-01  1.02768689e-04]
#  [-1.75654717e-03 -2.15049641e-01  1.02768689e-04  3.87190137e-01]]
#
# Predictive distribution ~ N(0.90781,1.03373)
# --------------------------------------------------
# Add data point (0.81564, 6.51319):
#
# Posterior mean:
# [[1.12388303]
#  [2.52550171]
#  [2.14374416]
#  [3.25819813]]
#
# Posterior variance:
# [[ 3.35968232e-02  2.03148896e-03 -5.29023120e-02 -1.72757007e-03]
#  [ 2.03148896e-03  1.67208748e-01 -2.77340510e-04 -2.15748044e-01]
#  [-5.29023120e-02 -2.77340510e-04  1.60429478e-01 -1.63704990e-03]
#  [-1.72757007e-03 -2.15748044e-01 -1.63704990e-03  3.86174965e-01]]
#
# Predictive distribution ~ N(6.37792,1.06814)
# --------------------------------------------------
# Add data point (-0.79930, -1.04698):
#
# Posterior mean:
# [[1.12375705]
#  [2.52261276]
#  [2.15051135]
#  [3.2545202 ]]
#
# Posterior variance:
# [[ 3.35959867e-02  2.01230560e-03 -5.28573761e-02 -1.75199255e-03]
#  [ 2.01230560e-03  1.66768812e-01  7.53184728e-04 -2.16308130e-01]
#  [-5.28573761e-02  7.53184728e-04  1.58015532e-01 -3.25080946e-04]
#  [-1.75199255e-03 -2.16308130e-01 -3.25080946e-04  3.85461915e-01]]
#
# Predictive distribution ~ N(-1.18058,1.05905)
# --------------------------------------------------
# Add data point (-0.57554, 0.02696):
#
# Posterior mean:
# [[1.12763497]
#  [2.50927863]
#  [2.15028586]
#  [3.26700726]]
#
# Posterior variance:
# [[ 3.33710728e-02  2.78566669e-03 -5.28442981e-02 -2.47622526e-03]
#  [ 2.78566669e-03  1.64109628e-01  7.08216100e-04 -2.13817872e-01]
#  [-5.28442981e-02  7.08216100e-04  1.58014772e-01 -2.82968986e-04]
#  [-2.47622526e-03 -2.13817872e-01 -2.82968986e-04  3.83129854e-01]]
#
# Predictive distribution ~ N(-0.22711,1.03457)
# --------------------------------------------------
# Add data point (-0.88004, 0.90329):
#
# Posterior mean:
# [[1.10825642]
#  [2.52009216]
#  [2.31125458]
#  [3.09077569]]
#
# Posterior variance:
# [[ 0.03330773  0.00282101 -0.05231818 -0.00305223]
#  [ 0.00282101  0.16408991  0.00041463 -0.21349645]
#  [-0.05231818  0.00041463  0.15364453  0.00450166]
#  [-0.00305223 -0.21349645  0.00450166  0.37789156]]
#
# Predictive distribution ~ N(-1.42610,1.08482)
# --------------------------------------------------
# Add data point (-0.30272, 0.20444):
#
# Posterior mean:
# [[1.10110075]
#  [2.53063889]
#  [2.32118147]
#  [3.07749112]]
#
# Posterior variance:
# [[ 0.03256416  0.00391697 -0.05128663 -0.00443269]
#  [ 0.00391697  0.16247457 -0.00110577 -0.21146179]
#  [-0.05128663 -0.00110577  0.15221348  0.00641674]
#  [-0.00443269 -0.21146179  0.00641674  0.37532872]]
#
# Predictive distribution ~ N(0.46236,1.03397)
# --------------------------------------------------
# Add data point (0.85311, 7.39961):
#
# Posterior mean:
# [[1.09902239]
#  [2.53583145]
#  [2.35232778]
#  [3.1038269 ]]
#
# Posterior variance:
# [[ 0.03254808  0.00395714 -0.05104569 -0.00422897]
#  [ 0.00395714  0.16237422 -0.00170773 -0.21197078]
#  [-0.05104569 -0.00170773  0.14860276  0.00336369]
#  [-0.00422897 -0.21197078  0.00336369  0.37274721]]
#
# Predictive distribution ~ N(6.90155,1.07669)
# --------------------------------------------------
# Add data point (-0.63073, -1.04364):
#
# Posterior mean:
# [[1.09170223]
#  [2.56695718]
#  [2.34670262]
#  [3.07857566]]
#
# Posterior variance:
# [[ 0.03243511  0.00443748 -0.0511325  -0.00461866]
#  [ 0.00443748  0.16033176 -0.00133861 -0.2103138 ]
#  [-0.0511325  -0.00133861  0.14853605  0.00306423]
#  [-0.00461866 -0.2103138   0.00306423  0.37140296]]
#
# Predictive distribution ~ N(-0.36625,1.03264)
# --------------------------------------------------
# Add data point (0.67181, 7.06901):
#
# Posterior mean:
# [[1.11546259]
#  [2.67073831]
#  [2.38131656]
#  [3.0092495 ]]
#
# Posterior variance:
# [[ 0.03232012  0.00393523 -0.05130001 -0.00428315]
#  [ 0.00393523  0.15813802 -0.00207028 -0.20884838]
#  [-0.05130001 -0.00207028  0.14829202  0.00355299]
#  [-0.00428315 -0.20884838  0.00355299  0.37042405]]
#
# Predictive distribution ~ N(4.89684,1.03897)
# --------------------------------------------------
# Add data point (0.76185, 6.81494):
#
# Posterior mean:
# [[1.11877589]
#  [2.69876008]
#  [2.41288303]
#  [3.01148779]]
#
# Posterior variance:
# [[ 0.03230742  0.00382783 -0.05142101 -0.00429173]
#  [ 0.00382783  0.15722962 -0.00309359 -0.20892094]
#  [-0.05142101 -0.00309359  0.14713927  0.00347125]
#  [-0.00429173 -0.20892094  0.00347125  0.37041825]]
#
# Predictive distribution ~ N(5.90694,1.04619)
# --------------------------------------------------
# Add data point (0.17967, 0.16178):
#
# Posterior mean:
# [[1.07227546]
#  [2.65306791]
#  [2.482992  ]
#  [3.070253  ]]
#
# Posterior variance:
# [[ 0.03136032  0.00289718 -0.04999305 -0.00309482]
#  [ 0.00289718  0.15631516 -0.00169045 -0.20774483]
#  [-0.04999305 -0.00169045  0.14498633  0.00166667]
#  [-0.00309482 -0.20774483  0.00166667  0.36890565]]
#
# Predictive distribution ~ N(1.64693,1.03390)
# --------------------------------------------------
# Add data point (-0.69434, -0.92136):
#
# Posterior mean:
# [[1.07032903]
#  [2.66450328]
#  [2.47663466]
#  [3.06453237]]
#
# Posterior variance:
# [[ 0.0313222   0.00312112 -0.05011755 -0.00320685]
#  [ 0.00312112  0.1549995  -0.00095903 -0.20708667]
#  [-0.05011755 -0.00095903  0.1445797   0.00130077]
#  [-0.00320685 -0.20708667  0.00130077  0.3685764 ]]
#
# Predictive distribution ~ N(-0.61156,1.03440)
# --------------------------------------------------
# Add data point (0.60734, 4.78896):
#
# Posterior mean:
# [[1.07709996]
#  [2.68891025]
#  [2.478046  ]
#  [3.04233988]]
#
# Posterior variance:
# [[ 0.03113256  0.00243754 -0.05015708 -0.00258529]
#  [ 0.00243754  0.15253542 -0.00110152 -0.20484615]
#  [-0.05015708 -0.00110152  0.14457147  0.00143033]
#  [-0.00258529 -0.20484615  0.00143033  0.36653917]]
#
# Predictive distribution ~ N(4.30578,1.03426)
# --------------------------------------------------
# Add data point (-0.56784, 0.12547):
#
# Posterior mean:
# [[1.08164061]
#  [2.67371118]
#  [2.47701899]
#  [3.05755743]]
#
# Posterior variance:
# [[ 0.03094114  0.00307829 -0.05011378 -0.00322682]
#  [ 0.00307829  0.1503906  -0.00124644 -0.20269873]
#  [-0.05011378 -0.00124644  0.14456167  0.00157543]
#  [-0.00322682 -0.20269873  0.00157543  0.36438913]]
#
# Predictive distribution ~ N(-0.19773,1.03017)
# --------------------------------------------------
# Add data point (-0.02319, 2.07392):
#
# Posterior mean:
# [[1.11314679]
#  [2.67329472]
#  [2.42593632]
#  [3.0590595 ]]
#
# Posterior variance:
# [[ 0.03001831  0.00309049 -0.04861754 -0.00327082]
#  [ 0.00309049  0.15039044 -0.00126622 -0.20269815]
#  [-0.04861754 -0.00126622  0.14213574  0.00164676]
#  [-0.00327082 -0.20269815  0.00164676  0.36438704]]
#
# Predictive distribution ~ N(1.05241,1.02990)
# --------------------------------------------------
# Add data point (0.45817, 3.37952):
#
# Posterior mean:
# [[1.11795718]
#  [2.68530908]
#  [2.42151973]
#  [3.0450866 ]]
#
# Posterior variance:
# [[ 2.95957011e-02  2.03499911e-03 -4.82295327e-02 -2.04326119e-03]
#  [ 2.03499911e-03  1.47754259e-01 -2.97134270e-04 -1.99632221e-01]
#  [-4.82295327e-02 -2.97134270e-04  1.41779494e-01  5.19698924e-04]
#  [-2.04326119e-03 -1.99632221e-01  5.19698924e-04  3.60821313e-01]]
#
# Predictive distribution ~ N(3.14951,1.03379)
# --------------------------------------------------
# Add data point (-0.82549, -1.52896):
#
# Posterior mean:
# [[1.11927684]
#  [2.68803129]
#  [2.40473472]
#  [3.05892955]]
#
# Posterior variance:
# [[ 2.95820504e-02  2.00684025e-03 -4.80559068e-02 -2.18645410e-03]
#  [ 2.00684025e-03  1.47696172e-01  6.10233947e-05 -1.99927601e-01]
#  [-4.80559068e-02  6.10233947e-05  1.39571115e-01  2.34099540e-03]
#  [-2.18645410e-03 -1.99927601e-01  2.34099540e-03  3.59319251e-01]]
#
# Predictive distribution ~ N(-1.18172,1.05485)
# --------------------------------------------------
# Add data point (0.08355, 0.80509):
#
# Posterior mean:
# [[1.10336491]
#  [2.68033235]
#  [2.43020155]
#  [3.06902724]]
#
# Posterior variance:
# [[ 0.02874234  0.00160055 -0.04671196 -0.00165357]
#  [ 0.00160055  0.14749959  0.00071129 -0.19966977]
#  [-0.04671196  0.00071129  0.13742015  0.00148813]
#  [-0.00165357 -0.19966977  0.00148813  0.35898109]]
#
# Predictive distribution ~ N(1.34608,1.02937)
# --------------------------------------------------
# Add data point (-0.00539, 2.00482):
#
# Posterior mean:
# [[1.12894386]
#  [2.68105004]
#  [2.38861643]
#  [3.06851254]]
#
# Posterior variance:
# [[ 0.02793984  0.00157803 -0.0454073  -0.00163743]
#  [ 0.00157803  0.14749896  0.00074789 -0.19966932]
#  [-0.0454073   0.00074789  0.13529909  0.00146188]
#  [-0.00163743 -0.19966932  0.00146188  0.35898076]]
#
# Predictive distribution ~ N(1.11457,1.02792)
# --------------------------------------------------
# Add data point (0.73390, 5.36256):
#
# Posterior mean:
# [[1.12804753]
#  [2.67402509]
#  [2.38220029]
#  [3.06974437]]
#
# Posterior variance:
# [[ 2.79245069e-02  1.45782607e-03 -4.55170889e-02 -1.61634863e-03]
#  [ 1.45782607e-03  1.46556839e-01 -1.12579162e-04 -1.99504115e-01]
#  [-4.55170889e-02 -1.12579162e-04  1.34513187e-01  1.61276135e-03]
#  [-1.61634863e-03 -1.99504115e-01  1.61276135e-03  3.58951794e-01]]
#
# Predictive distribution ~ N(5.58696,1.03865)
# --------------------------------------------------
# Add data point (0.18309, 2.09470):
#
# Posterior mean:
# [[1.1378397 ]
#  [2.68396658]
#  [2.36713173]
#  [3.05656147]]
#
# Posterior variance:
# [[ 2.72346838e-02  7.57484040e-04 -4.44555634e-02 -6.87660950e-04]
#  [ 7.57484040e-04  1.45845817e-01  9.65133363e-04 -1.98561266e-01]
#  [-4.44555634e-02  9.65133363e-04  1.32879672e-01  1.83662006e-04]
#  [-6.87660950e-04 -1.98561266e-01  1.83662006e-04  3.57701530e-01]]
#
# Predictive distribution ~ N(1.72734,1.02914)
# --------------------------------------------------
# Add data point (-0.59215, 1.55352):
#
# Posterior mean:
# [[1.15778244]
#  [2.60652598]
#  [2.36981785]
#  [3.13162059]]
#
# Posterior variance:
# [[ 2.71096997e-02  1.24281593e-03 -4.44723977e-02 -1.15806774e-03]
#  [ 1.24281593e-03  1.43961201e-01  1.03050366e-03 -1.96734606e-01]
#  [-4.44723977e-02  1.03050366e-03  1.32877404e-01  1.20302004e-04]
#  [-1.15806774e-03 -1.96734606e-01  1.20302004e-04  3.55931044e-01]]
#
# Predictive distribution ~ N(-0.20493,1.02827)
# --------------------------------------------------
# Add data point (0.20268, 1.74905):
#
# Posterior mean:
# [[1.15628352]
#  [2.60483325]
#  [2.37209655]
#  [3.13385585]]
#
# Posterior variance:
# [[ 2.64768153e-02  5.28098283e-04 -4.35102676e-02 -2.14279561e-04]
#  [ 5.28098283e-04  1.43154069e-01  2.11703918e-03 -1.95668784e-01]
#  [-4.35102676e-02  2.11703918e-03  1.31414745e-01 -1.31447351e-03]
#  [-2.14279561e-04 -1.95668784e-01 -1.31447351e-03  3.54523621e-01]]
#
# Predictive distribution ~ N(1.80778,1.02861)
# --------------------------------------------------
# Add data point (-0.37213, 1.24379):
#
# Posterior mean:
# [[1.17379805]
#  [2.56821836]
#  [2.3495988 ]
#  [3.18065225]]
#
# Posterior variance:
# [[ 2.60779229e-02  1.36200012e-03 -4.29978827e-02 -1.28006492e-03]
#  [ 1.36200012e-03  1.41410761e-01  1.04587625e-03 -1.93440714e-01]
#  [-4.29978827e-02  1.04587625e-03  1.30756577e-01  5.45482587e-05]
#  [-1.28006492e-03 -1.93440714e-01  5.45482587e-05  3.51675990e-01]]
#
# Predictive distribution ~ N(0.37956,1.02878)
# --------------------------------------------------
# Add data point (0.10437, 2.08114):
#
# Posterior mean:
# [[1.18909605]
#  [2.5776717 ]
#  [2.32496519]
#  [3.16813551]]
#
# Posterior variance:
# [[ 0.02543224  0.000963   -0.04195817 -0.00075177]
#  [ 0.000963    0.1411642   0.00168836 -0.19311426]
#  [-0.04195817  0.00168836  0.12908238 -0.00079614]
#  [-0.00075177 -0.19311426 -0.00079614  0.35124374]]
#
# Predictive distribution ~ N(1.48705,1.02623)
# --------------------------------------------------
# Add data point (-0.79858, -0.93810):
#
# Posterior mean:
# [[1.1889945 ]
#  [2.57693978]
#  [2.32730299]
#  [3.16659801]]
#
# Posterior variance:
# [[ 2.54294378e-02  9.42810538e-04 -4.18936751e-02 -7.94185861e-04]
#  [ 9.42810538e-04  1.41018658e-01  2.15324374e-03 -1.93419994e-01]
#  [-4.18936751e-02  2.15324374e-03  1.27597509e-01  1.80412513e-04]
#  [-7.94185861e-04 -1.93419994e-01  1.80412513e-04  3.50601494e-01]]
#
# Predictive distribution ~ N(-0.99741,1.04442)
# --------------------------------------------------
# Add data point (-0.36850, 1.73923):
#
# Posterior mean:
# [[1.21435674]
#  [2.52336329]
#  [2.29419269]
#  [3.23571859]]
#
# Posterior variance:
# [[ 0.02506225  0.00171848 -0.04141431 -0.0017949 ]
#  [ 0.00171848  0.13938009  0.00114061 -0.19130603]
#  [-0.04141431  0.00114061  0.1269717   0.00148684]
#  [-0.0017949  -0.19130603  0.00148684  0.34787421]]
#
# Predictive distribution ~ N(0.43412,1.02768)
# --------------------------------------------------
# Add data point (0.97556, 10.15727):
#
# Posterior mean:
# [[1.19825117]
#  [2.47974697]
#  [2.38618333]
#  [3.38840981]]
#
# Posterior variance:
# [[ 2.48836818e-02  1.23489938e-03 -4.03943904e-02 -1.01983358e-04]
#  [ 1.23489938e-03  1.38070472e-01  3.90270301e-03 -1.86721346e-01]
#  [-4.03943904e-02  3.90270301e-03  1.21146196e-01 -8.18265303e-03]
#  [-1.01983358e-04 -1.86721346e-01 -8.18265303e-03  3.31824232e-01]]
#
# Predictive distribution ~ N(9.03434,1.13193)
# --------------------------------------------------
# Add data point (-0.20308, 0.56983):
#
# Posterior mean:
# [[1.19389001]
#  [2.48450908]
#  [2.39304226]
#  [3.38182084]]
#
# Posterior variance:
# [[ 0.02436967  0.00179617 -0.03958598 -0.00087857]
#  [ 0.00179617  0.1374576   0.00301998 -0.18587336]
#  [-0.03958598  0.00301998  0.11987479 -0.00696129]
#  [-0.00087857 -0.18587336 -0.00696129  0.33065094]]
#
# Predictive distribution ~ N(0.75971,1.02561)
# --------------------------------------------------
# Add data point (0.64284, 4.51801):
#
# Posterior mean:
# [[1.19250045]
#  [2.47797048]
#  [2.39147969]
#  [3.38732866]]
#
# Posterior variance:
# [[ 0.02429226  0.00143194 -0.03967303 -0.00057176]
#  [ 0.00143194  0.1357437   0.00261039 -0.18442965]
#  [-0.03967303  0.00261039  0.11977691 -0.00661628]
#  [-0.00057176 -0.18442965 -0.00661628  0.32943483]]
#
# Predictive distribution ~ N(4.67358,1.02978)
# --------------------------------------------------
# Add data point (0.31722, 1.90549):
#
# Posterior mean:
# [[1.18399803]
#  [2.46203359]
#  [2.40255192]
#  [3.40751275]]
#
# Posterior variance:
# [[ 0.0238743   0.00064852 -0.03912874  0.00042044]
#  [ 0.00064852  0.13427526  0.0036306  -0.18256987]
#  [-0.03912874  0.0036306   0.11906812 -0.00790837]
#  [ 0.00042044 -0.18256987 -0.00790837  0.32707941]]
#
# Predictive distribution ~ N(2.31552,1.02797)
# --------------------------------------------------
# Add data point (0.52536, 2.40487):
#
# Posterior mean:
# [[1.16788731]
#  [2.40737548]
#  [2.40913306]
#  [3.46758615]]
#
# Posterior variance:
# [[ 2.36977565e-02  4.95543497e-05 -3.90566254e-02  1.07874939e-03]
#  [ 4.95543497e-05  1.32243187e-01  3.87526966e-03 -1.80336469e-01]
#  [-3.90566254e-02  3.87526966e-03  1.19038659e-01 -8.17728036e-03]
#  [ 1.07874939e-03 -1.80336469e-01 -8.17728036e-03  3.24624734e-01]]
#
# Predictive distribution ~ N(3.60035,1.02789)
# --------------------------------------------------
# Add data point (0.03561, 2.39866):
#
# Posterior mean:
# [[1.19426445]
#  [2.41268   ]
#  [2.3658947 ]
#  [3.46163089]]
#
# Posterior variance:
# [[ 2.31514190e-02 -6.03158717e-05 -3.81610491e-02  1.20209790e-03]
#  [-6.03158717e-05  1.32221091e-01  4.05537292e-03 -1.80311664e-01]
#  [-3.81610491e-02  4.05537292e-03  1.17570598e-01 -8.37947774e-03]
#  [ 1.20209790e-03 -1.80311664e-01 -8.37947774e-03  3.24596886e-01]]
#
# Predictive distribution ~ N(1.28335,1.02322)
# --------------------------------------------------
# Add data point (0.28967, 0.87338):
#
# Posterior mean:
# [[1.16893833]
#  [2.36929136]
#  [2.40056385]
#  [3.51725605]]
#
# Posterior variance:
# [[ 0.02276326 -0.00072531 -0.03762969  0.00205464]
#  [-0.00072531  0.13108182  0.00496569 -0.1788511 ]
#  [-0.03762969  0.00496569  0.11684322 -0.00954652]
#  [ 0.00205464 -0.1788511  -0.00954652  0.32272441]]
#
# Predictive distribution ~ N(2.14215,1.02582)
# --------------------------------------------------
# Add data point (0.38546, 1.84081):
#
# Posterior mean:
# [[1.15569463]
#  [2.33791821]
#  [2.4152803 ]
#  [3.55604474]]
#
# Posterior variance:
# [[ 0.02248148 -0.00139282 -0.03731658  0.00287992]
#  [-0.00139282  0.12950055  0.00570743 -0.17689607]
#  [-0.03731658  0.00570743  0.11649529 -0.01046359]
#  [ 0.00287992 -0.17689607 -0.01046359  0.32030728]]
#
# Predictive distribution ~ N(2.61938,1.02618)
# --------------------------------------------------
# Add data point (-0.24186, 0.24278):
#
# Posterior mean:
# [[1.14688895]
#  [2.35069305]
#  [2.42884892]
#  [3.53871923]]
#
# Posterior variance:
# [[ 0.02206784 -0.00079274 -0.03667921  0.00206608]
#  [-0.00079274  0.12862998  0.00478277 -0.17571538]
#  [-0.03667921  0.00478277  0.11551317 -0.00920953]
#  [ 0.00206608 -0.17571538 -0.00920953  0.318706  ]]
#
# Predictive distribution ~ N(0.67036,1.02476)
# --------------------------------------------------
# Add data point (-0.92507, -1.11657):
#
# Posterior mean:
# [[1.14099387]
#  [2.36419322]
#  [2.46635339]
#  [3.48361112]]
#
# Posterior variance:
# [[ 0.02197279 -0.00057505 -0.03607445  0.00117746]
#  [-0.00057505  0.12813146  0.00339783 -0.17368039]
#  [-0.03607445  0.00339783  0.11166571 -0.00355619]
#  [ 0.00117746 -0.17368039 -0.00355619  0.31039912]]
#
# Predictive distribution ~ N(-1.69322,1.09044)
# --------------------------------------------------
# Add data point (0.94577, 7.14226):
#
# Posterior mean:
# [[1.15333585]
#  [2.3933868 ]
#  [2.38608755]
#  [3.36283033]]
#
# Posterior variance:
# [[ 0.02188526 -0.00078209 -0.0355052   0.00203404]
#  [-0.00078209  0.12764172  0.00474432 -0.17165425]
#  [-0.0355052   0.00474432  0.10796362 -0.00912695]
#  [ 0.00203404 -0.17165425 -0.00912695  0.30201647]]
#
# Predictive distribution ~ N(8.39614,1.09656)
# --------------------------------------------------
# Add data point (0.22742, 1.36661):
#
# Posterior mean:
# [[1.1437382 ]
#  [2.3806158 ]
#  [2.4000533 ]
#  [3.37919572]]
#
# Posterior variance:
# [[ 0.02149873 -0.00129641 -0.03494276  0.00269312]
#  [-0.00129641  0.12695734  0.00549273 -0.17077725]
#  [-0.03494276  0.00549273  0.1071452  -0.01008599]
#  [ 0.00269312 -0.17077725 -0.01008599  0.30089264]]
#
# Predictive distribution ~ N(1.84903,1.02346)
# --------------------------------------------------
# Add data point (0.24920, 1.85906):
#
# Posterior mean:
# [[1.14226326]
#  [2.37844452]
#  [2.40214996]
#  [3.38197061]]
#
# Posterior variance:
# [[ 0.02114436 -0.00181808 -0.03443902  0.00335981]
#  [-0.00181808  0.12618939  0.00623429 -0.16979581]
#  [-0.03443902  0.00623429  0.10642913 -0.0110337 ]
#  [ 0.00335981 -0.16979581 -0.0110337   0.29963836]]
#
# Predictive distribution ~ N(1.93649,1.02325)
# --------------------------------------------------
# Add data point (-0.63601, 0.19446):
#
# Posterior mean:
# [[1.14565347]
#  [2.36224188]
#  [2.40553135]
#  [3.39543133]]
#
# Posterior variance:
# [[ 0.02108944 -0.0015556  -0.0344938   0.00314175]
#  [-0.0015556   0.12493492  0.00649609 -0.16875363]
#  [-0.0344938   0.00649609  0.10637449 -0.0112512 ]
#  [ 0.00314175 -0.16875363 -0.0112512   0.29877254]]
#
# Predictive distribution ~ N(-0.25724,1.02504)
# --------------------------------------------------
# Add data point (-0.36884, 0.53429):
#
# Posterior mean:
# [[1.14734282]
#  [2.35839503]
#  [2.40333548]
#  [3.40034098]]
#
# Posterior variance:
# [[ 0.0208138  -0.00092793 -0.03413551  0.00234066]
#  [-0.00092793  0.12350564  0.00568022 -0.16692946]
#  [-0.03413551  0.00568022  0.10590878 -0.01020993]
#  [ 0.00234066 -0.16692946 -0.01020993  0.29644441]]
#
# Predictive distribution ~ N(0.43381,1.02487)
# --------------------------------------------------
# Add data point (0.31172, 2.80309):
#
# Posterior mean:
# [[1.15719651]
#  [2.37725274]
#  [2.3905708 ]
#  [3.37655568]]
#
# Posterior variance:
# [[ 0.02052229 -0.0014858  -0.03375789  0.00304432]
#  [-0.0014858   0.12243799  0.00640291 -0.16558283]
#  [-0.03375789  0.00640291  0.1054196  -0.01112145]
#  [ 0.00304432 -0.16558283 -0.01112145  0.2947459 ]]
#
# Predictive distribution ~ N(2.23281,1.02358)
# --------------------------------------------------
# Add data point (-0.98493, -2.68494):
#
# Posterior mean:
# [[1.1643401 ]
#  [2.35512753]
#  [2.35251622]
#  [3.44253949]]
#
# Posterior variance:
# [[ 0.02035775 -0.00097618 -0.03288136  0.00152448]
#  [-0.00097618  0.12085958  0.00368811 -0.16087558]
#  [-0.03288136  0.00368811  0.10075024 -0.00302514]
#  [ 0.00152448 -0.16087558 -0.00302514  0.2807075 ]]
#
# Predictive distribution ~ N(-2.16242,1.11967)
# --------------------------------------------------
# Add data point (-0.28629, 1.26458):
#
# Posterior mean:
# [[1.17592561]
#  [2.33474715]
#  [2.33594738]
#  [3.46890267]]
#
# Posterior variance:
# [[ 0.02004458 -0.00042528 -0.03243349  0.00081186]
#  [-0.00042528  0.11989048  0.00290025 -0.15962199]
#  [-0.03243349  0.00290025  0.10010973 -0.002006  ]
#  [ 0.00081186 -0.15962199 -0.002006    0.27908591]]
#
# Predictive distribution ~ N(0.61758,1.02331)
# --------------------------------------------------
# Add data point (-0.69279, -0.58977):
#
# Posterior mean:
# [[1.17541679]
#  [2.33802629]
#  [2.33433434]
#  [3.46690983]]
#
# Posterior variance:
# [[ 0.02002482 -0.0002979  -0.03249615  0.00073445]
#  [-0.0002979   0.11906957  0.00330407 -0.15912309]
#  [-0.03249615  0.00330407  0.09991109 -0.00225141]
#  [ 0.00073445 -0.15912309 -0.00225141  0.27878272]]
#
# Predictive distribution ~ N(-0.47676,1.02495)
# --------------------------------------------------
# Add data point (0.11993, 2.09460):
#
# Posterior mean:
# [[1.18687853]
#  [2.34610151]
#  [2.31633015]
#  [3.4564009 ]]
#
# Posterior variance:
# [[ 0.0196514  -0.00056099 -0.03190958  0.00107682]
#  [-0.00056099  0.11888421  0.00371733 -0.15888188]
#  [-0.03190958  0.00371733  0.09898971 -0.00278922]
#  [ 0.00107682 -0.15888188 -0.00278922  0.2784688 ]]
#
# Predictive distribution ~ N(1.50751,1.02028)
# --------------------------------------------------
# Add data point (0.69718, 4.73748):
#
# Posterior mean:
# [[1.18534898]
#  [2.33484383]
#  [2.3096953 ]
#  [3.46260179]]
#
# Posterior variance:
# [[ 0.01963493 -0.00068221 -0.03198103  0.0011436 ]
#  [-0.00068221  0.11799198  0.00319148 -0.15839042]
#  [-0.03198103  0.00319148  0.09867979 -0.00249957]
#  [ 0.0011436  -0.15839042 -0.00249957  0.2781981 ]]
#
# Predictive distribution ~ N(5.10915,1.02748)
# --------------------------------------------------
# ...
# --------------------------------------------------
# Add data point (-0.47914, -0.17009):
#
# Posterior mean:
# [[0.98684275]
#  [2.21138425]
#  [3.03201568]
#  [3.84874768]]
#
# Posterior variance:
# [[ 2.08724450e-03 -9.24614489e-05 -3.45018662e-03 -3.31601960e-05]
#  [-9.24614489e-05  1.73044223e-02 -4.79299943e-04 -2.40008900e-02]
#  [-3.45018662e-03 -4.79299943e-04  1.05238107e-02  1.40839576e-03]
#  [-3.31601960e-05 -2.40008900e-02  1.40839576e-03  3.99717648e-02]]
#
# Predictive distribution ~ N(0.20000,1.00311)
# --------------------------------------------------
# Add data point (-0.04597, 0.16546):
#
# Posterior mean:
# [[0.98533333]
#  [2.21202641]
#  [3.03448239]
#  [3.84797323]]
#
# Posterior variance:
# [[ 2.08290976e-03 -9.06172828e-05 -3.44310272e-03 -3.53842510e-05]
#  [-9.06172828e-05  1.73036377e-02 -4.82313710e-04 -2.39999438e-02]
#  [-3.44310272e-03 -4.82313710e-04  1.05122341e-02  1.41203034e-03]
#  [-3.53842510e-05 -2.39999438e-02  1.41203034e-03  3.99706237e-02]]
#
# Predictive distribution ~ N(0.88968,1.00211)
# --------------------------------------------------
# Add data point (-0.67103, -1.21954):
#
# Posterior mean:
# [[0.98477667]
#  [2.21632774]
#  [3.03338812]
#  [3.84370835]]
#
# Posterior variance:
# [[ 2.08254595e-03 -8.78061154e-05 -3.44381789e-03 -3.81715919e-05]
#  [-8.78061154e-05  1.72819157e-02 -4.76787572e-04 -2.39784059e-02]
#  [-3.44381789e-03 -4.76787572e-04  1.05108282e-02  1.40655104e-03]
#  [-3.81715919e-05 -2.39784059e-02  1.40655104e-03  3.99492684e-02]]
#
# Predictive distribution ~ N(-0.29796,1.00286)
# --------------------------------------------------
# Add data point (-0.23116, 1.05100):
#
# Posterior mean:
# [[0.98566482]
#  [2.21456374]
#  [3.03209737]
#  [3.84606209]]
#
# Posterior variance:
# [[ 2.07887179e-03 -8.05086202e-05 -3.43847820e-03 -4.79087248e-05]
#  [-8.05086202e-05  1.72674217e-02 -4.87393072e-04 -2.39590663e-02]
#  [-3.43847820e-03 -4.87393072e-04  1.05030680e-02  1.42070209e-03]
#  [-4.79087248e-05 -2.39590663e-02  1.42070209e-03  3.99234634e-02]]
#
# Predictive distribution ~ N(0.58826,1.00258)
# --------------------------------------------------
# Add data point (0.97941, 11.09406):
#
# Posterior mean:
# [[0.98378728]
#  [2.20597438]
#  [3.04257148]
#  [3.86752606]]
#
# Posterior variance:
# [[ 2.07709267e-03 -8.86477212e-05 -3.42855315e-03 -2.75699067e-05]
#  [-8.86477212e-05  1.72301869e-02 -4.41987910e-04 -2.38660202e-02]
#  [-3.42855315e-03 -4.41987910e-04  1.04476996e-02  1.30723902e-03]
#  [-2.75699067e-05 -2.38660202e-02  1.30723902e-03  3.96909502e-02]]
#
# Predictive distribution ~ N(9.69636,1.01405)
# --------------------------------------------------
# Add data point (0.82451, 8.65621):
#
# Posterior mean:
# [[0.98323635]
#  [2.20668297]
#  [3.04907891]
#  [3.87304883]]
#
# Posterior variance:
# [[ 2.07697610e-03 -8.84977933e-05 -3.42717627e-03 -2.64013679e-05]
#  [-8.84977933e-05  1.72299941e-02 -4.43758805e-04 -2.38675231e-02]
#  [-3.42717627e-03 -4.43758805e-04  1.04314364e-02  1.29343666e-03]
#  [-2.64013679e-05 -2.38675231e-02  1.29343666e-03  3.96792364e-02]]
#
# Predictive distribution ~ N(7.04635,1.00467)
# --------------------------------------------------
# Add data point (-0.13664, 0.43852):
#
# Posterior mean:
# [[0.98264992]
#  [2.20737512]
#  [3.04999833]
#  [3.8721344 ]]
#
# Posterior variance:
# [[ 2.07288423e-03 -8.36682437e-05 -3.42076094e-03 -3.27818630e-05]
#  [-8.36682437e-05  1.72242938e-02 -4.51330688e-04 -2.38599924e-02]
#  [-3.42076094e-03 -4.51330688e-04  1.04213783e-02  1.30344015e-03]
#  [-3.27818630e-05 -2.38599924e-02  1.30344015e-03  3.96692872e-02]]
#
# Predictive distribution ~ N(0.72810,1.00228)
# --------------------------------------------------
# Add data point (-0.00007, 0.72440):
#
# Posterior mean:
# [[0.98211603]
#  [2.20739698]
#  [3.05087937]
#  [3.87214241]]
#
# Posterior variance:
# [[ 2.06859625e-03 -8.34926902e-05 -3.41368481e-03 -3.27174820e-05]
#  [-8.34926902e-05  1.72242867e-02 -4.51620390e-04 -2.38599950e-02]
#  [-3.41368481e-03 -4.51620390e-04  1.04097011e-02  1.30333390e-03]
#  [-3.27174820e-05 -2.38599950e-02  1.30333390e-03  3.96692862e-02]]
#
# Predictive distribution ~ N(0.98196,1.00207)
# --------------------------------------------------
# Add data point (0.94285, 9.15742):
#
# Posterior mean:
# [[0.98197129]
#  [2.20682413]
#  [3.05175773]
#  [3.87374596]]
#
# Posterior variance:
# [[ 2.06745876e-03 -8.79946930e-05 -3.40678183e-03 -2.01153670e-05]
#  [-8.79946930e-05  1.72064684e-02 -4.24299418e-04 -2.38101177e-02]
#  [-3.40678183e-03 -4.24299418e-04  1.03678096e-02  1.22685638e-03]
#  [-2.01153670e-05 -2.38101177e-02  1.22685638e-03  3.95296684e-02]]
#
# Predictive distribution ~ N(9.02243,1.01055)
# --------------------------------------------------
# Add data point (0.84978, 9.54524):
#
# Posterior mean:
# [[0.98096577]
#  [2.20601966]
#  [3.06113043]
#  [3.8839938 ]]
#
# Posterior variance:
# [[ 2.06722978e-03 -8.81778881e-05 -3.40464746e-03 -1.77817037e-05]
#  [-8.81778881e-05  1.72063218e-02 -4.22591809e-04 -2.38082506e-02]
#  [-3.40464746e-03 -4.22591809e-04  1.03479145e-02  1.20510369e-03]
#  [-1.77817037e-05 -2.38082506e-02  1.20510369e-03  3.95058846e-02]]
#
# Predictive distribution ~ N(7.44960,1.00540)
# --------------------------------------------------
# Add data point (-0.93416, -1.78003):
#
# Posterior mean:
# [[0.98113012]
#  [2.20543355]
#  [3.06010443]
#  [3.88581255]]
#
# Posterior variance:
# [[ 2.06658388e-03 -8.58743751e-05 -3.40061511e-03 -2.49296635e-05]
#  [-8.58743751e-05  1.71981067e-02 -4.36972507e-04 -2.37827586e-02]
#  [-3.40061511e-03 -4.36972507e-04  1.03227408e-02  1.24972799e-03]
#  [-2.49296635e-05 -2.37827586e-02  1.24972799e-03  3.94267811e-02]]
#
# Predictive distribution ~ N(-1.57637,1.00811)
# --------------------------------------------------
# Add data point (0.28177, 1.04166):
#
# Posterior mean:
# [[0.97955594]
#  [2.2017081 ]
#  [3.06248209]
#  [3.89091654]]
#
# Posterior variance:
# [[ 2.06345262e-03 -9.32848316e-05 -3.39588559e-03 -1.47770785e-05]
#  [-9.32848316e-05  1.71805691e-02 -4.25779592e-04 -2.37587315e-02]
#  [-3.39588559e-03 -4.25779592e-04  1.03155972e-02  1.23439330e-03]
#  [-1.47770785e-05 -2.37587315e-02  1.23439330e-03  3.93938631e-02]]
#
# Predictive distribution ~ N(1.93010,1.00261)
# --------------------------------------------------
# Add data point (-0.82840, -0.71523):
#
# Posterior mean:
# [[0.97951272]
#  [2.2014431 ]
#  [3.06327706]
#  [3.89046812]]
#
# Posterior variance:
# [[ 2.06341989e-03 -9.34854761e-05 -3.39528369e-03 -1.51165887e-05]
#  [-9.34854761e-05  1.71793389e-02 -4.22089088e-04 -2.37608132e-02]
#  [-3.39528369e-03 -4.22089088e-04  1.03045264e-02  1.24063800e-03]
#  [-1.51165887e-05 -2.37608132e-02  1.24063800e-03  3.93903406e-02]]
#
# Predictive distribution ~ N(-0.95366,1.00408)
# --------------------------------------------------
# Add data point (0.50854, 3.20942):
#
# Posterior mean:
# [[0.97929361]
#  [2.20039968]
#  [3.0634279 ]
#  [3.89174078]]
#
# Posterior variance:
# [[ 2.06213340e-03 -9.96117644e-05 -3.39439807e-03 -7.64431793e-06]
#  [-9.96117644e-05  1.71501655e-02 -4.17871737e-04 -2.37252302e-02]
#  [-3.39439807e-03 -4.17871737e-04  1.03039167e-02  1.23549407e-03]
#  [-7.64431793e-06 -2.37252302e-02  1.23549407e-03  3.93469399e-02]]
#
# Predictive distribution ~ N(3.40233,1.00281)
# --------------------------------------------------
# Add data point (-0.51802, -0.27732):
#
# Posterior mean:
# [[0.9788161 ]
#  [2.20269925]
#  [3.0636598 ]
#  [3.88890711]]
#
# Posterior variance:
# [[ 2.06068836e-03 -9.26527811e-05 -3.39369629e-03 -1.62196107e-05]
#  [-9.26527811e-05  1.71166525e-02 -4.21251355e-04 -2.36839335e-02]
#  [-3.39369629e-03 -4.21251355e-04  1.03035759e-02  1.23965865e-03]
#  [-1.62196107e-05 -2.36839335e-02  1.23965865e-03  3.92960515e-02]]
#
# Predictive distribution ~ N(0.11930,1.00305)
# --------------------------------------------------
# Add data point (-0.32636, 0.70785):
#
# Posterior mean:
# [[0.97925906]
#  [2.20144452]
#  [3.06309603]
#  [3.8905661 ]]
#
# Posterior variance:
# [[ 2.05770396e-03 -8.41991394e-05 -3.38989796e-03 -2.73969801e-05]
#  [-8.41991394e-05  1.70927066e-02 -4.32010545e-04 -2.36522723e-02]
#  [-3.38989796e-03 -4.32010545e-04  1.02987417e-02  1.25388440e-03]
#  [-2.73969801e-05 -2.36522723e-02  1.25388440e-03  3.92541892e-02]]
#
# Predictive distribution ~ N(0.45180,1.00286)
# --------------------------------------------------
# Add data point (-0.24966, 1.44011):
#
# Posterior mean:
# [[0.98089863]
#  [2.19792421]
#  [3.06076147]
#  [3.89525783]]
#
# Posterior variance:
# [[ 2.05422420e-03 -7.67277571e-05 -3.38494316e-03 -3.73545292e-05]
#  [-7.67277571e-05  1.70766649e-02 -4.42648972e-04 -2.36308925e-02]
#  [-3.38494316e-03 -4.42648972e-04  1.02916866e-02  1.26806286e-03]
#  [-3.73545292e-05 -2.36308925e-02  1.26806286e-03  3.92256951e-02]]
#
# Predictive distribution ~ N(0.56232,1.00261)
# --------------------------------------------------
# Add data point (0.45676, 2.38741):
#
# Posterior mean:
# [[0.98010587]
#  [2.19466765]
#  [3.06156013]
#  [3.89939196]]
#
# Posterior variance:
# [[ 2.05251444e-03 -8.37512117e-05 -3.38322068e-03 -2.84384089e-05]
#  [-8.37512117e-05  1.70478134e-02 -4.35573243e-04 -2.35942662e-02]
#  [-3.38322068e-03 -4.35573243e-04  1.02899513e-02  1.25908037e-03]
#  [-2.84384089e-05 -2.35942662e-02  1.25908037e-03  3.91791989e-02]]
#
# Predictive distribution ~ N(2.99283,1.00283)
# --------------------------------------------------
# Add data point (-0.47434, 1.28932):
#
# Posterior mean:
# [[0.98153899]
#  [2.1884905 ]
#  [3.06049046]
#  [3.90719664]]
#
# Posterior variance:
# [[ 2.05074021e-03 -7.61037507e-05 -3.38189640e-03 -3.81007897e-05]
#  [-7.61037507e-05  1.70148506e-02 -4.41281246e-04 -2.35526186e-02]
#  [-3.38189640e-03 -4.41281246e-04  1.02889629e-02  1.26629230e-03]
#  [-3.81007897e-05 -2.35526186e-02  1.26629230e-03  3.91265781e-02]]
#
# Predictive distribution ~ N(0.21505,1.00305)
# --------------------------------------------------
# Add data point (0.57492, 3.23646):
#
# Posterior mean:
# [[0.98087285]
#  [2.18464999]
#  [3.060486  ]
#  [3.91152106]]
#
# Posterior variance:
# [[ 2.04996456e-03 -8.05756403e-05 -3.38190160e-03 -3.30654319e-05]
#  [-8.05756403e-05  1.69890687e-02 -4.41311226e-04 -2.35235880e-02]
#  [-3.38190160e-03 -4.41311226e-04  1.02889628e-02  1.26632606e-03]
#  [-3.30654319e-05 -2.35235880e-02  1.26632606e-03  3.90938896e-02]]
#
# Predictive distribution ~ N(3.99180,1.00271)
# --------------------------------------------------
# Add data point (-0.88538, -0.69532):
#
# Posterior mean:
# [[0.98058373]
#  [2.18513955]
#  [3.06287931]
#  [3.90847134]]
#
# Posterior variance:
# [[ 2.04970916e-03 -8.01431805e-05 -3.37978743e-03 -3.57594523e-05]
#  [-8.01431805e-05  1.69883364e-02 -4.44891166e-04 -2.35190262e-02]
#  [-3.37978743e-03 -4.44891166e-04  1.02714615e-02  1.28862739e-03]
#  [-3.57594523e-05 -2.35190262e-02  1.28862739e-03  3.90654718e-02]]
#
# Predictive distribution ~ N(-1.26578,1.00570)
# --------------------------------------------------
# Add data point (-0.16297, 1.80525):
#
# Posterior mean:
# [[0.98278136]
#  [2.18206694]
#  [3.05949343]
#  [3.91255027]]
#
# Posterior variance:
# [[ 2.04582485e-03 -7.47123071e-05 -3.37380284e-03 -4.29690014e-05]
#  [-7.47123071e-05  1.69807432e-02 -4.53258532e-04 -2.35089462e-02]
#  [-3.37380284e-03 -4.53258532e-04  1.02622410e-02  1.29973517e-03]
#  [-4.29690014e-05 -2.35089462e-02  1.29973517e-03  3.90520904e-02]]
#
# Predictive distribution ~ N(0.69149,1.00232)
# --------------------------------------------------
# Add data point (0.35962, 3.52431):
#
# Posterior mean:
# [[0.98464012]
#  [2.18780546]
#  [3.05696607]
#  [3.90489143]]
#
# Posterior variance:
# [[ 2.04333327e-03 -8.24044972e-05 -3.37041506e-03 -3.27027183e-05]
#  [-8.24044972e-05  1.69569952e-02 -4.42799478e-04 -2.34772512e-02]
#  [-3.37041506e-03 -4.42799478e-04  1.02576347e-02  1.28577613e-03]
#  [-3.27027183e-05 -2.34772512e-02  1.28577613e-03  3.90097891e-02]]
#
# Predictive distribution ~ N(2.34836,1.00275)
# --------------------------------------------------
# Add data point (0.06519, 0.43397):
#
# Posterior mean:
# [[0.98321161]
#  [2.18708917]
#  [3.05933465]
#  [3.90598347]]
#
# Posterior variance:
# [[ 2.03924669e-03 -8.44536046e-05 -3.36363918e-03 -2.95786682e-05]
#  [-8.44536046e-05  1.69559678e-02 -4.39401900e-04 -2.34756848e-02]
#  [-3.36363918e-03 -4.39401900e-04  1.02463997e-02  1.28059621e-03]
#  [-2.95786682e-05 -2.34756848e-02  1.28059621e-03  3.90074009e-02]]
#
# Predictive distribution ~ N(1.13988,1.00207)
# --------------------------------------------------
# Add data point (-0.74624, -1.54382):
#
# Posterior mean:
# [[0.98297684]
#  [2.19022705]
#  [3.05725538]
#  [3.9040464 ]]
#
# Posterior variance:
# [[ 2.03918858e-03 -8.36769785e-05 -3.36415381e-03 -3.00580928e-05]
#  [-8.36769785e-05  1.69455876e-02 -4.32523641e-04 -2.34692769e-02]
#  [-3.36415381e-03 -4.32523641e-04  1.02418420e-02  1.27635014e-03]
#  [-3.00580928e-05 -2.34692769e-02  1.27635014e-03  3.90034452e-02]]
#
# Predictive distribution ~ N(-0.57134,1.00300)
# --------------------------------------------------
# Add data point (-0.48397, -1.67259):
#
# Posterior mean:
# [[0.98056348]
#  [2.20089651]
#  [3.05893355]
#  [3.89061861]]
#
# Posterior variance:
# [[ 2.03751635e-03 -7.62840228e-05 -3.36299099e-03 -3.93623205e-05]
#  [-7.62840228e-05  1.69129034e-02 -4.37664470e-04 -2.34281430e-02]
#  [-3.36299099e-03 -4.37664470e-04  1.02410334e-02  1.28282001e-03]
#  [-3.93623205e-05 -2.34281430e-02  1.28282001e-03  3.89516770e-02]]
#
# Predictive distribution ~ N(0.19084,1.00303)
# --------------------------------------------------
# Add data point (0.47802, 2.14020):
#
# Posterior mean:
# [[0.97931856]
#  [2.19547474]
#  [3.06004031]
#  [3.89739985]]
#
# Posterior variance:
# [[ 2.03601185e-03 -8.28362839e-05 -3.36165346e-03 -3.11671227e-05]
#  [-8.28362839e-05  1.68843676e-02 -4.31839395e-04 -2.33924520e-02]
#  [-3.36165346e-03 -4.31839395e-04  1.02398443e-02  1.27553434e-03]
#  [-3.11671227e-05 -2.33924520e-02  1.27553434e-03  3.89070368e-02]]
#
# Predictive distribution ~ N(3.15373,1.00280)
# --------------------------------------------------
# Add data point (0.29510, 0.79563):
#
# Posterior mean:
# [[0.97726534]
#  [2.19038236]
#  [3.06310526]
#  [3.90435944]]
#
# Posterior variance:
# [[ 2.03306793e-03 -9.01377546e-05 -3.35725892e-03 -2.11884447e-05]
#  [-9.01377546e-05  1.68662585e-02 -4.20940110e-04 -2.33677029e-02]
#  [-3.35725892e-03 -4.20940110e-04  1.02332843e-02  1.26063865e-03]
#  [-2.11884447e-05 -2.33677029e-02  1.26063865e-03  3.88732131e-02]]
#
# Predictive distribution ~ N(1.99074,1.00260)
# --------------------------------------------------
# Add data point (-0.40297, -0.97045):
#
# Posterior mean:
# [[0.97527733]
#  [2.19745287]
#  [3.06520115]
#  [3.89516452]]
#
# Posterior variance:
# [[ 2.03074737e-03 -8.18844679e-05 -3.35481242e-03 -3.19215185e-05]
#  [-8.18844679e-05  1.68369050e-02 -4.29641301e-04 -2.33295298e-02]
#  [-3.35481242e-03 -4.29641301e-04  1.02307051e-02  1.27195420e-03]
#  [-3.19215185e-05 -2.33295298e-02  1.27195420e-03  3.88235704e-02]]
#
# Predictive distribution ~ N(0.33263,1.00298)
# --------------------------------------------------
# Add data point (0.20454, 1.60711):
#
# Posterior mean:
# [[0.97531618]
#  [2.19751807]
#  [3.06513886]
#  [3.8950729 ]]
#
# Posterior variance:
# [[ 2.02724610e-03 -8.77611961e-05 -3.34919846e-03 -2.36637331e-05]
#  [-8.77611961e-05  1.68270411e-02 -4.20218494e-04 -2.33156694e-02]
#  [-3.34919846e-03 -4.20218494e-04  1.02217036e-02  1.25871358e-03]
#  [-2.36637331e-05 -2.33156694e-02  1.25871358e-03  3.88040943e-02]]
#
# Predictive distribution ~ N(1.58638,1.00235)
# --------------------------------------------------
# Add data point (-0.61816, 0.47177):
#
# Posterior mean:
# [[0.97580214]
#  [2.19442232]
#  [3.06545141]
#  [3.89850661]]
#
# Posterior variance:
# [[ 2.02659625e-03 -8.36213889e-05 -3.34961641e-03 -2.82554731e-05]
#  [-8.36213889e-05  1.68006689e-02 -4.17555972e-04 -2.32864182e-02]
#  [-3.34961641e-03 -4.17555972e-04  1.02214348e-02  1.25576040e-03]
#  [-2.82554731e-05 -2.32864182e-02  1.25576040e-03  3.87716498e-02]]
#
# Predictive distribution ~ N(-0.13021,1.00283)
# --------------------------------------------------
# Add data point (-0.66283, -0.26807):
#
# Posterior mean:
# [[0.97580162]
#  [2.19442624]
#  [3.06545052]
#  [3.89850265]]
#
# Posterior variance:
# [[ 2.02621462e-03 -8.07701305e-05 -3.35026550e-03 -3.11350485e-05]
#  [-8.07701305e-05  1.67793668e-02 -4.12706559e-04 -2.32649046e-02]
#  [-3.35026550e-03 -4.12706559e-04  1.02203308e-02  1.25086282e-03]
#  [-3.11350485e-05 -2.32649046e-02  1.25086282e-03  3.87499225e-02]]
#
# Predictive distribution ~ N(-0.26722,1.00278)
# --------------------------------------------------

# %% [markdown]
# # 收斂次數

# %%
converge_times
# Out:
# 1080

# %% [markdown]
# # 畫圖

# %%
def plot(num_points, x, mean, variance, title, plot_x, plot_y, n):
    mean_predict     = np.zeros(1000)
    variance_predict = np.zeros(1000)
    for i in range(len(x)):         #i = 0~999  每個點都是高斯分佈
        X                   = np.array([[x[i]**j for j in range(n)]])
        mean_predict[i]     = matrixMul(X, mean)[0][0]                             # 預測機率最大的mean就是y值
        variance_predict[i] = 1/a + matrixMul(matrixMul(X, variance), X.T)[0][0]   # 機率最大的variance
    
    plt.plot(plot_x[:num_points], plot_y[:num_points], 'bo')    # 畫前面幾個點(藍色)
    plt.plot(x, mean_predict, 'k-')                             # 畫機率最高的線(黑色)
    plt.plot(x, mean_predict+variance_predict, 'r-')            # 畫一個variance(紅色)
    plt.plot(x, mean_predict-variance_predict, 'r-') 
    plt.xlim(-2,2)
    plt.ylim(-20,20)
    plt.title(title)
    plt.show()

# %%
x = np.linspace(-2, 2, 1000)  # x座標
plot(0,             x, w.reshape((n, 1)),  np.zeros((n,n)),  'Ground truth',      plot_x, plot_y, n)  # Ground truth 就是:var matrix是零，a*1 + b*x + c*x^2 + d*x^3的abcd就是真值
plot(converge_times,x, plot_mean[2],       plot_variance[2], 'Predict result',    plot_x, plot_y, n)
plot(10,            x, plot_mean[0],       plot_variance[0], 'After 10 incomes',  plot_x, plot_y, n)
plot(50,            x, plot_mean[1],       plot_variance[1], 'After 50 incomes',  plot_x, plot_y, n)
